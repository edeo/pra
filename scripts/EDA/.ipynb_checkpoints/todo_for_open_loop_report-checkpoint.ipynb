# %% [markdown]
# folowing the advice on i hate notebooks only move forward.
#
# 1. current inventory - make a table
# 2.  pending - make a table
# 3. make a list of all omb control numbers in inventory
# 4. make a list of all omb control numbers in pending
# 5. combine those lists
# 6. search the federal register for all those omb control numbers
# 7.  save those to a list
# 8. create a table of all the notices
# 9. search for all the new notices for dol going back a year
# 10. use the inventory to make sure that collections that were new and approved are all in that list of notices
# 11. use the pending to make sure the collections that are new and submitted are in that list.
#
# finding open loops:
#
# 12. what is :
#             1. in inventory
#             2. expiring in the next year.
#             3. does not have a 60 day notice published within the last 9 months.
#
# 13. what is :
#             1. in inventory
#             2. expiring in the next year.
#             3. has a 60 day notice published within the last 9 months.
#             4. has not been submitted to oira
#
# 14. What are new collections that have had 60 day notices published in the last year that have not been submitted to oira?
#
# how can we do this on a daily basis? ( automated / semi automated)
#
# how can we add data to find when the agency sends the package to ocio? to show the real cycle time?
#
# notes
#
# try an find the last published notice date for all the omb control numbers in inventory

# %%
import pycurl
import requests
import os 
from lxml import etree
import pandas as pd 
import datetime
import requests
from bs4 import BeautifulSoup
import json
import pycurl
import requests
import os 
from lxml import etree
import pandas as pd 
import datetime
import requests
from bs4 import BeautifulSoup
import json
import numpy as np
import shutil


dol_agency_codes = [
1220,
1225,
1205,
1219,
1218,
1250,
1245,
1240,
1293,
1290,
1235,
1210]

# %%
def get_xpath_strings(dol_agency_codes):       
    xpath_strings = []
    xpath_string_prefix = '//InformationCollectionRequest[.//AgencyCode/text()[. = "'
    xpath_string_suffix = '"]]'
    
    for number in dol_agency_codes:
        new_string = xpath_string_prefix+str(number)+xpath_string_suffix
        xpath_strings.append(new_string) 
    
    return(xpath_strings)
    

def inventory_to_list(file,dol_agency_codes):
    xpath_strings= get_xpath_strings(dol_agency_codes)
    
    tree = etree.parse(file)
    root = tree.getroot()
    all_results = []

    for string in xpath_strings:
      results = []
      req = root.xpath(string)
      for request in req:       
        try:
         results.append({
           "omb_control_number": request.xpath('./OMBControlNumber//text()')[0],
           "icr_reference_number": request.xpath('./ICRReferenceNumber//text()')[0],
           "Title": request.xpath('./Title//text()')[0],
           #"Abstract": request.xpath('./Abstract//text()')[0],
           "AgencyCode": str(request.xpath('./AgencyCode//text()')[0]).strip(),
           "ICRTypeCode": str(request.xpath('./ICRTypeCode//text()')[0]).strip(),
           "expiration_date": str(request.xpath('./Expiration/ExpirationDate//text()')[0]).strip(),
           "ICR_status": str(request.xpath('./ICRStatus//text()')[0]).strip()})
        except:
            results.append({
              "omb_control_number": request.xpath('./OMBControlNumber//text()')[0],
              "icr_reference_number": request.xpath('./ICRReferenceNumber//text()')[0],
              "Title": request.xpath('./Title//text()')[0],
              #"Abstract": request.xpath('./Abstract//text()')[0],
              "AgencyCode": str(request.xpath('./AgencyCode//text()')[0]).strip(),
              "ICRTypeCode": str(request.xpath('./ICRTypeCode//text()')[0]).strip(),
              "expiration_date": str(request.xpath('./Expiration/ExpirationDate//text()')[0]).strip(),
              "ICR_status": "None"})
            
      all_results.append(results) 
    return(all_results)
    
    
    
def inventory_list_to_table(file,all_results):    
    dol_inventory_row_list = []
    
    for list in all_results:
      for row in list:
        dol_inventory_row_list.append(row)
    
    dol_inventory_table = pd.DataFrame(dol_inventory_row_list)
    dol_inventory_table['file_date'] = file
    return(dol_inventory_table)    




def create_pending_df_from_xml(file):
    tree = etree.parse(file)
    root = tree.getroot()
    req = root.xpath('//InformationCollectionRequest')
    results = []
    for request in req:
        try:
            results.append({
                "omb_control_number": request.xpath('./OMBControlNumber//text()')[0],
                "icr_reference_number": request.xpath('./ICRReferenceNumber//text()')[0],
                "AgencyCode": str(request.xpath('./AgencyCode//text()')[0]).strip(),
                "Title": request.xpath('./Title//text()')[0],
                "submission_date": str(request.xpath('./SubmissionDate/Date//text()')[0]).strip()})
        except:
            pass
   
    df = pd.DataFrame(results)
    df['Agency'] = df['AgencyCode'].str[:2]
    return(df)


def dol_pending(pending_df):
    dol_pending = pending_df[pending_df['Agency']=='12']
    return(dol_pending)

# %% [markdown]
# current inventory - make a table

# %%
# first get the file 
os.chdir('/home/jupyter-ed/projects/pra/data/inventory')

# %%
os.listdir()
# Out:
# ['2020-07-01_inventory.xml',
#  'new_in_pending_today_table.csv',
#  '2020-07-06_inventory.xml',
#  '2020-07-10_inventory.xml',
#  'pending.csv',
#  '.ipynb_checkpoints',
#  '2020-06-23_inventory.xml',
#  '2020-07-02_inventory.xml',
#  '2020-06-25_inventory.xml',
#  '2020-06-28_inventory.xml',
#  '2020-07-18_inventory.xml',
#  '2020-07-29_inventory.xml',
#  '2020-07-16_inventory.xml',
#  '2020-07-26_inventory.xml',
#  '2020-07-14_inventory.xml',
#  '2020-07-15_inventory.xml',
#  '2020-07-11_inventory.xml',
#  '2020-07-28_inventory.xml',
#  '2020-07-24_inventory.xml',
#  '2020-07-17_inventory.xml',
#  '2020-07-12_inventory.xml',
#  '2020-07-08_inventory.xml',
#  '2020-07-25_inventory.xml',
#  '2020-07-13_inventory.xml',
#  '2020-06-29_inventory.xml',
#  '2020-07-20_inventory.xml',
#  '2020-07-09_inventory.xml',
#  '2020-06-27_inventory.xml',
#  '2020-07-21_inventory.xml',
#  '2020-07-23_inventory.xml',
#  '2020-06-24_inventory.xml',
#  '2020-07-05_inventory.xml',
#  '2020-07-19_inventory.xml',
#  '2020-07-22_inventory.xml',
#  '2020-07-04_inventory.xml',
#  'gone_from_pending_today_table.csv',
#  '2020-07-27_inventory.xml']

# %%
inventory_file = '2020-07-27_inventory.xml'

# %%
xpath_strings = get_xpath_strings(dol_agency_codes)

# %%
inventory_list =inventory_to_list(inventory_file,dol_agency_codes)

# %%
inventory_df = inventory_list_to_table(inventory_file,inventory_list)

# %% [markdown]
# pending - make a table

# %%
# first get the file 
os.chdir('/home/jupyter-ed/projects/pra/data/pending')

# %%
os.listdir()
# Out:
# ['2020-07-08_pending.xml',
#  '2020-07-14_pending.xml',
#  '2020-07-12_pending.xml',
#  '2020-07-13_pending.xml',
#  '.ipynb_checkpoints',
#  '2020-07-29_pending.xml',
#  '2020-07-04_pending.xml',
#  '2020-07-09_pending.xml',
#  '2020-07-23_pending.xml',
#  '2020-07-05_pending.xml',
#  '2020-07-11_pending.xml',
#  '2020-07-16_pending.xml',
#  '2020-07-15_pending.xml',
#  '2020-06-25_pending.xml',
#  '2020-06-24_pending.xml',
#  '2020-06-28_pending.xml',
#  '2020-07-02_pending.xml',
#  '2020-07-24_pending.xml',
#  '2020-07-22_pending.xml',
#  '2020-07-17_pending.xml',
#  '2020-06-29_pending.xml',
#  '2020-07-06_pending.xml',
#  '2020-07-21_pending.xml',
#  '2020-06-27_pending.xml',
#  '2020-07-26_pending.xml',
#  '2020-07-28_pending.xml',
#  '2020-07-27_pending.xml',
#  '2020-07-01_pending.xml',
#  '2020-07-18_pending.xml',
#  '2020-07-19_pending.xml',
#  '2020-07-20_pending.xml',
#  '2020-07-10_pending.xml',
#  '2020-07-25_pending.xml',
#  '2020-06-23_pending.xml']

# %%
pending_file ='2020-07-27_pending.xml'

# %%
pending_df_all = create_pending_df_from_xml(pending_file)

# %%
pending_df_dol = dol_pending(pending_df_all)

# %%
pending_df_dol
# Out:
#     omb_control_number icr_reference_number AgencyCode  \
# 434          1220-0163      202006-1220-004       1220
# 435          1220-0109      202004-1220-003       1220
# 436          1220-0039      202002-1220-001       1220
# 437          1210-0132      202003-1210-007       1210
# 438          1210-0090      202003-1210-006       1210
# 439          1210-0039      202003-1210-004       1210
# 440          1210-0126      202003-1210-003       1210
# 441          1210-0121      202003-1210-002       1210
# 442          1205-0528      202004-1205-005       1205
# 443          1205-0134      201912-1205-004       1205
# 444          1219-0143      202003-1219-004       1219
# 445          1219-0152      202003-1219-002       1219
# 446          1219-0048      202003-1219-001       1219
# 447          1219-0078      202002-1219-006       1219
# 448          1219-0003      202002-1219-005       1219
# 449          1219-0024      202002-1219-004       1219
# 450          1219-0089      202001-1219-001       1219
# 451          1219-0124      201912-1219-001       1219
# 452          1219-0138      201910-1219-004       1219
# 453          1218-0267      202006-1218-006       1218
# 454          1218-0143      202005-1218-001       1218
# 455          1218-0197      202003-1218-009       1218
# 456          1218-0255      202003-1218-008       1218
# 457          1218-0145      202003-1218-007       1218
# 458          1218-0221      202003-1218-005       1218
# 459          1218-0216      202003-1218-004       1218
# 460          1218-0202      201912-1218-010       1218
# 461          1218-0065      201911-1218-005       1218
# 462          1218-0236      201911-1218-004       1218
# 463          1218-0185      201911-1218-003       1218
# 464          1218-0205      201911-1218-001       1218
# 465          1230-0014      202006-1230-001       1230
# 466          1240-0035      202003-1240-001       1240
# 467          1240-0033      202002-1240-005       1240
# 468          1240-0003      202002-1240-002       1240
# 469          1240-0026      202001-1240-003       1240
# 470          1240-0014      202001-1240-002       1240
# 471          1240-0011      202001-1240-001       1240
# 472          1240-0022      201911-1240-006       1240
# 473          1240-0027      201911-1240-004       1240
# 474          1240-0048      201910-1240-005       1240
# 475          1240-0055      201906-1240-001       1240
# 476          1235-0001      202006-1235-001       1235
# 477          1235-0016      202001-1235-009       1235
# 478          1235-0015      202001-1235-008       1235
# 758          1212-0009      202007-1212-001       1212
# 759          1212-0017      202006-1212-001       1212
#
#                                                  Title   submission_date  \
# 434                Consumer Price Index Housing Survey  2020-06-29-04:00
# 435         National Longitudinal Survey of Youth 1979  2020-06-17-04:00
# 436  Consumer Price Index Commodities and Services ...  2020-07-21-04:00
# 437  Default Investment Alternatives under Particip...  2020-05-27-04:00
# 438  Disclosures for Participant Directed Individua...  2020-05-27-04:00
# 439  Summary Plan Description Requirements Under th...  2020-05-27-04:00
# 440         Defined Benefit Plan Annual Funding Notice  2020-05-27-04:00
# 441  Consent to Receive Employee Benefit Plan Discl...  2020-05-27-04:00
# 442          American Apprenticeship Initiative Grants  2020-06-24-04:00
# 443  Agricultural Recruitment System Forms Affectin...  2020-05-04-04:00
# 444  Qualification/Certification Program Request fo...  2020-07-17-04:00
# 445  Periodic Medical Surveillance Examinations for...  2020-07-17-04:00
# 446                         Respirator Program Records  2020-07-17-04:00
# 447  Mine Rescue Teams, Arrangements for Emergency ...  2020-02-28-05:00
# 448           Radiation Sampling and Exposure Records   2020-06-23-04:00
# 449  Application for Waiver of Surface Sanitary Fac...  2020-03-19-04:00
# 450  Safety Defects; Examination, Correction, and R...  2020-06-23-04:00
# 451  Health Standards for Diesel Particulate Matter...  2020-04-09-04:00
# 452  Safety Standards for Underground Coal Mine Ven...  2020-01-22-05:00
# 453  Beryllium Standard for General Industry (29 CF...  2020-07-22-04:00
# 454  Presence Sensing Device Initiation (PSDI) Stan...  2020-06-18-04:00
# 455  Construction Fall Protection Systems Criteria,...  2020-05-04-04:00
# 456  Occupational Safety and Health Administration ...  2020-04-15-04:00
# 457           Formaldehyde Standard (29 CFR 1910.1048)  2020-04-28-04:00
# 458  Crawler, Locomotive, and Truck Cranes Standard...  2020-04-29-04:00
# 459            Aerial Lifts Standard (29 CFR 1926.453)  2020-04-29-04:00
# 460  Hazardous Waste Operations and Emergency Respo...  2020-01-29-05:00
# 461  Access to Employee Exposure and Medical Record...  2020-04-15-04:00
# 462  Regulations Containing Procedures for Handling...  2020-03-27-04:00
# 463  Cadmium in General Industry Standard (29 CFR 1...  2020-04-01-04:00
# 464  Personal Protective Equipment for General Indu...  2020-02-25-05:00
# 465  Retaining Employment and Talent after Injury/I...  2020-07-17-04:00
# 466  Description of Coal Mine Work and Other Employ...  2020-06-09-04:00
# 467  Coal Mine Operator Response to Schedule for Su...  2020-06-16-04:00
# 468  Employer's First Report of Injury or Occupatio...  2020-06-25-04:00
# 469  Application for Continuation of Death Benefit ...  2020-05-27-04:00
# 470  Administration of the Longshore and Harbor Wor...  2020-05-27-04:00
# 471  Application for Approval of a Representative's...  2020-05-12-04:00
# 472  Notice of Law Enforcement Officer's Injury or ...  2020-03-30-04:00
# 473  Survivor's Form for Benefits Under the Black L...  2020-03-27-04:00
# 474             Notice of Issuance of Insurance Policy  2020-02-06-05:00
# 475  Authorization Request Forms/Certification/Lett...  2020-02-12-05:00
# 476  Fair Labor Standards Act Special Employment Pr...  2020-07-08-04:00
# 477  Application for a Farm Labor Contractor or Far...  2020-03-26-04:00
# 478     Report of Construction Contractor's Wage Rates  2020-05-28-04:00
# 758             Payment of Premiums (29 CFR part 4007)  2020-07-21-04:00
# 759  Liability for Termination of Single-Employer P...  2020-06-10-04:00
#
#     Agency
# 434     12
# 435     12
# 436     12
# 437     12
# 438     12
# 439     12
# 440     12
# 441     12
# 442     12
# 443     12
# 444     12
# 445     12
# 446     12
# 447     12
# 448     12
# 449     12
# 450     12
# 451     12
# 452     12
# 453     12
# 454     12
# 455     12
# 456     12
# 457     12
# 458     12
# 459     12
# 460     12
# 461     12
# 462     12
# 463     12
# 464     12
# 465     12
# 466     12
# 467     12
# 468     12
# 469     12
# 470     12
# 471     12
# 472     12
# 473     12
# 474     12
# 475     12
# 476     12
# 477     12
# 478     12
# 758     12
# 759     12

# %% [markdown]
# 3. make a list of all omb control numbers in inventory

# %%
pending_omb_cntrl_number_list = pending_df_dol.omb_control_number.to_list()

# %%
len(pending_omb_cntrl_number_list)
# Out:
# 47

# %% [markdown]
# 4. make a list of all omb control numbers in pending

# %%
inventory_omb_cntrl_number_list = inventory_df.omb_control_number.to_list()

# %%
len(inventory_omb_cntrl_number_list)
# Out:
# 474

# %%
icr_list = inventory_omb_cntrl_number_list

# %% [markdown]
# 5. combine those lists

# %%
icr_list.extend(pending_omb_cntrl_number_list)

# %%
len(icr_list)
# Out:
# 521

# %%
icr_list[-3]
# Out:
# '1235-0015'

# %% [markdown]
# example
# https://www.federalregister.gov/api/v1/documents.json?conditions%5Bagencies%5D%5B%5D=labor-department&conditions%5Bterm%5D=
# 1235-0015
# &conditions%5Btype%5D%5B%5D=NOTICE&order=newest"

# %% [markdown]
# 6. search the federal register for all those omb control numbers
# 7.  save those to a list
# 8. create a table of all the notices

# %%
folder_name = datetime.datetime.now().strftime('notice_%Y-%m-%d')   
os.chdir('/home/jupyter-ed/projects/pra/scripts/EDA')
# define the name of the directory to be created
os.mkdir(folder_name)
os.chdir(folder_name)

# %%
def omb_cntrl_number_frn_link(omb_control_number):
    prefix = "https://www.federalregister.gov/api/v1/documents.json?conditions%5Bagencies%5D%5B%5D=labor-department&conditions%5Bterm%5D="
    suffix= "&conditions%5Btype%5D%5B%5D=NOTICE"
    query_url = prefix + omb_control_number + suffix
    return(query_url)

# %%
def get_omb_frn(query_url,omb_control_number):
    fr_request = requests.get(query_url)
    fr_json = fr_request.json()
    json_file_name = 'notices_'+omb_control_number+'.json'
    with open(json_file_name, 'w') as f:
        json.dump(fr_json, f)

# %%
test_omb_number ='1235-0015'

# %%
test_link = omb_cntrl_number_frn_link(test_omb_number)

# %%
test_link
# Out:
# 'https://www.federalregister.gov/api/v1/documents.json?conditions%5Bagencies%5D%5B%5D=labor-department&conditions%5Bterm%5D=1235-0015&conditions%5Btype%5D%5B%5D=NOTICE'

# %%
get_omb_frn(test_link,test_omb_number)

# %%
for omb_number in icr_list:
    omb_link = omb_cntrl_number_frn_link(omb_number)
    get_omb_frn(omb_link,omb_number)

# %% [markdown]
# read in the json files and create a table

# %%
test_link
# Out:
# 'https://www.federalregister.gov/api/v1/documents.json?conditions%5Bagencies%5D%5B%5D=labor-department&conditions%5Bterm%5D=1235-0015&conditions%5Btype%5D%5B%5D=NOTICE'

# %%
fr_request = requests.get(test_link)
fr_json = fr_request.json()

# %%
fr_json
# Out:
# {'count': 10,
#  'description': "Documents matching '1235-0015', from Labor Department, and of type Notice",
#  'total_pages': 1,
#  'results': [{'title': "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Report of Construction Contractor's Wage Rates",
#    'type': 'Notice',
#    'abstract': 'The Department of Labor (DOL) is submitting this Wage and Hour Division (WHD)-sponsored information collection request (ICR) to the Office of Management and Budget (OMB) for review and approval in accordance with the Paperwork Reduction Act of 1995 (PRA). Public comments on the ICR are invited.',
#    'document_number': '2020-11458',
#    'html_url': 'https://www.federalregister.gov/documents/2020/05/28/2020-11458/agency-information-collection-activities-submission-for-omb-review-comment-request-report-of',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2020-05-28/pdf/2020-11458.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2020-11458.pdf?1590583571',
#    'publication_date': '2020-05-28',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Office of the Secretary'}],
#    'excerpts': 'Report of Construction Contractor\'s Wage Rates. \n \n OMB Control Number: <span class="match">1235-0015</span>. \n \n Affected Public: Private Sector: Businesses or other for-profits,'},
#   {'title': "Agency Information Collection Activities; Comment Request; Information Collections: Report of Construction Contractor's Wage Rates",
#    'type': 'Notice',
#    'abstract': "The Department of Labor, as part of its continuing effort to reduce paperwork and respondent burden, conducts a preclearance consultation program to provide the general public and Federal agencies with an opportunity to comment on proposed and/or continuing collections of information in accordance with the Paperwork Reduction Act of 1995 (PRA95). This program helps to ensure that requested data can be provided in the desired format, reporting burden (time and financial resources) is minimized, collection instruments are clearly understood, and the impact of collection requirements on respondents can be properly assessed. Currently, the Wage and Hour Division is soliciting comments concerning its proposed extension of the Office of Management and Budget (OMB) approved information collection request (ICR) titled, ``Report of Construction Contractor's Wage Rates.'' A copy of the proposed information collection request can be obtained by contacting the office listed below in the FOR FURTHER INFORMATION CONTACT section of this Notice.",
#    'document_number': '2019-25457',
#    'html_url': 'https://www.federalregister.gov/documents/2019/11/25/2019-25457/agency-information-collection-activities-comment-request-information-collections-report-of',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2019-11-25/pdf/2019-25457.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2019-25457.pdf?1574430322',
#    'publication_date': '2019-11-25',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Wage and Hour Division',
#      'name': 'Wage and Hour Division',
#      'id': 524,
#      'url': 'https://www.federalregister.gov/agencies/wage-and-hour-division',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/524',
#      'parent_id': 271,
#      'slug': 'wage-and-hour-division'}],
#    'excerpts': '\n \n ADDRESSES: \n You may submit comments identified by Control Number <span class="match">1235-0015</span>, by either one of the following methods: Email: WHDPRAComments@dol.gov; … Title: Report of Construction Contractor\'s Wage Rates. \n \n OMB Numbers: <span class="match">1235-0015</span>. \n \n Affected Public: Businesses or other for-profits, Federal Government'},
#   {'title': 'Agency Information Collection Activities; Announcement of OMB Approvals',
#    'type': 'Notice',
#    'abstract': "The Department of Labor, Wage and Hour Division announces that the Office of Management and Budget (OMB) has approved certain collections of information listed in the SUPPLEMENTARY INFORMATION below, following the Wage and Hour Division's submission of requests for approvals under the Paperwork Reduction Act of 1995 (PRA). This notice describes the information collections that have been approved or re-approved, the corresponding OMB Control Numbers, and their current expiration dates.",
#    'document_number': '2020-03606',
#    'html_url': 'https://www.federalregister.gov/documents/2020/02/24/2020-03606/agency-information-collection-activities-announcement-of-omb-approvals',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2020-02-24/pdf/2020-03606.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2020-03606.pdf?1582292730',
#    'publication_date': '2020-02-24',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Wage and Hour Division',
#      'name': 'Wage and Hour Division',
#      'id': 524,
#      'url': 'https://www.federalregister.gov/agencies/wage-and-hour-division',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/524',
#      'parent_id': 271,
#      'slug': 'wage-and-hour-division'}],
#    'excerpts': 'for this information collection is June 30, 2021. \n • OMB Control No. <span class="match">1235-0015</span>, Report of Construction Contractor\'s Wage Rates. The expiration date for'},
#   {'title': 'Agency Information Collection Activities; Announcement of OMB Approvals',
#    'type': 'Notice',
#    'abstract': "The Department of Labor, Wage and Hour Division announces that the Office of Management and Budget (OMB) has approved certain collections of information listed in the SUPPLEMENTARY INFORMATION below, following the Wage and Hour Division's submission of requests for approvals under the Paperwork Reduction Act of 1995 (PRA). This notice describes the information collections that have been approved or re-approved, the corresponding OMB Control Numbers, and their current expiration dates.",
#    'document_number': '2017-12231',
#    'html_url': 'https://www.federalregister.gov/documents/2017/06/13/2017-12231/agency-information-collection-activities-announcement-of-omb-approvals',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-06-13/pdf/2017-12231.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2017-12231.pdf?1497271569',
#    'publication_date': '2017-06-13',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Wage and Hour Division',
#      'name': 'Wage and Hour Division',
#      'id': 524,
#      'url': 'https://www.federalregister.gov/agencies/wage-and-hour-division',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/524',
#      'parent_id': 271,
#      'slug': 'wage-and-hour-division'}],
#    'excerpts': 'this information collection is February 28, 2018. \n • OMB Control No. <span class="match">1235-0015</span>, Report of Construction Contractor\'s Wage Rates. The expiration date for'},
#   {'title': "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Report of Construction Contractor's Wage Rates",
#    'type': 'Notice',
#    'abstract': "The Department of Labor (DOL) is submitting the Wage and Hour Division (WHD) sponsored information collection request (ICR) titled, ``Report of Construction Contractor's Wage Rates,'' to the Office of Management and Budget (OMB) for review and approval for continued use, without change, in accordance with the Paperwork Reduction Act of 1995 (PRA). Public comments on the ICR are invited.",
#    'document_number': '2017-04369',
#    'html_url': 'https://www.federalregister.gov/documents/2017/03/07/2017-04369/agency-information-collection-activities-submission-for-omb-review-comment-request-report-of',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2017-03-07/pdf/2017-04369.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2017-04369.pdf?1488807949',
#    'publication_date': '2017-03-07',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Office of the Secretary'}],
#    'excerpts': 'obtains OMB approval for this information collection under Control Number <span class="match">1235-0015</span>. \n OMB authorization for an ICR cannot be for more than three (3) years … appropriate consideration, comments should mention OMB Control Number <span class="match">1235-0015</span>. The OMB is particularly interested in comments that: \n • Evaluate whether … Report of Construction Contractor\'s Wage Rates. \n \n OMB Control Number: <span class="match">1235-0015</span>. \n \n Affected Public: Private Sector—businesses or other for-profits, not-for-profit'},
#   {'title': "Agency Information Collection Activities; Comment Request; Information Collections: Report of Construction Contractor's Wage Rates",
#    'type': 'Notice',
#    'abstract': "The Department of Labor (DOL) is soliciting comments concerning a proposed extension of the information collection request (ICR) titled, ``Report of Construction Contractor's Wage Rates.'' This comment request is part of continuing Departmental efforts to reduce paperwork and respondent burden in accordance with the Paperwork Reduction Act of 1995 (PRA), 44 U.S.C. 3501 et seq. This program helps to ensure that requested data can be provided in the desired format, reporting burden (time and financial resources) is minimized, collection instruments are clearly understood, and the impact of collection requirements on respondents can be properly assessed. A copy of the proposed information request can be obtained by contacting the office listed below in the FOR FURTHER INFORMATION CONTACT section of this Notice.",
#    'document_number': '2016-25079',
#    'html_url': 'https://www.federalregister.gov/documents/2016/10/18/2016-25079/agency-information-collection-activities-comment-request-information-collections-report-of',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2016-10-18/pdf/2016-25079.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2016-25079.pdf?1476708342',
#    'publication_date': '2016-10-18',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Wage and Hour Division',
#      'name': 'Wage and Hour Division',
#      'id': 524,
#      'url': 'https://www.federalregister.gov/agencies/wage-and-hour-division',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/524',
#      'parent_id': 271,
#      'slug': 'wage-and-hour-division'}],
#    'excerpts': '\n \n ADDRESSES: \n You may submit comments identified by Control Number <span class="match">1235-0015</span>, by either one of the following methods: Email: WHDPRAComments@dol.gov; … Title: Report of Construction Contractor\'s Wage Rates. \n \n OMB Number: <span class="match">1235-0015</span>. \n \n Affected Public: Business or other for-profit, Not-for-profit institutions'},
#   {'title': "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Report of Construction Contractor's Wage Rates",
#    'type': 'Notice',
#    'abstract': "The Department of Labor (DOL) is submitting the Wage and Hour Division (WHD) sponsored information collection request (ICR) revision titled, ``Report of Construction Contractor's Wage Rates,'' to the Office of Management and Budget (OMB) for review and approval for use in accordance with the Paperwork Reduction Act (PRA) of 1995 (44 U.S.C. 3501 et seq.).",
#    'document_number': '2014-06396',
#    'html_url': 'https://www.federalregister.gov/documents/2014/03/24/2014-06396/agency-information-collection-activities-submission-for-omb-review-comment-request-report-of',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2014-03-24/pdf/2014-06396.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2014-06396.pdf?1395407063',
#    'publication_date': '2014-03-24',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Office of the Secretary'}],
#    'excerpts': 'obtains OMB approval for this information collection under Control Number <span class="match">1235-0015</span>. The current approval is scheduled to expire on March 31, 2014; however … appropriate consideration, comments should mention OMB Control Number <span class="match">1235-0015</span>. The OMB is particularly interested in comments that: \n • Evaluate whether … Report of Construction Contractor\'s Wage Rates. \n \n OMB Control Number: <span class="match">1235-0015</span>. \n \n Affected Public: Private Sector—businesses or other for-profits and'},
#   {'title': 'Proposed Revision and Extension of the Approval of Information Collection Requirements',
#    'type': 'Notice',
#    'abstract': "The Department of Labor, as part of its continuing effort to reduce paperwork and respondent burden, conducts a preclearance consultation program to provide the general public and Federal agencies with an opportunity to comment on proposed and/or continuing collections of information in accordance with the Paperwork Reduction Act of 1995 (PRA95). 44 U.S.C. 3506(c)(2)(A). This program helps to ensure that requested data can be provided in the desired format, reporting burden (time and financial resources) is minimized, collection instruments are clearly understood, and the impact of collection requirements on respondents can be properly assessed. Currently, the Wage and Hour Division is soliciting comments concerning its proposal to revise and extend Office of Management and Budget (OMB) approval of the Information Collection: Report of Construction Contractor's Wage Rates. A copy of the proposed information collection request can be obtained by contacting the office listed below in the FOR FURTHER INFORMATION CONTACT section of this Notice.",
#    'document_number': '2013-28882',
#    'html_url': 'https://www.federalregister.gov/documents/2013/12/03/2013-28882/proposed-revision-and-extension-of-the-approval-of-information-collection-requirements',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2013-12-03/pdf/2013-28882.pdf',
#    'public_inspection_pdf_url': 'https://s3.amazonaws.com/public-inspection.federalregister.gov/2013-28882.pdf?1385992923',
#    'publication_date': '2013-12-03',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Wage and Hour Division',
#      'name': 'Wage and Hour Division',
#      'id': 524,
#      'url': 'https://www.federalregister.gov/agencies/wage-and-hour-division',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/524',
#      'parent_id': 271,
#      'slug': 'wage-and-hour-division'}],
#    'excerpts': '\n \n ADDRESSES: \n You may submit comments identified by Control Number <span class="match">1235-0015</span>, by either one of the following methods: \n \n Email: WHDPRAComments@dol … Title: Report of Construction Contractor\'s Wage Rates. \n \n OMB Numbers: <span class="match">1235-0015</span>. \n \n Affected Public: Businesses or other for-profits, Federal Government'},
#   {'title': "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Report of Construction Contractor's Wage Rates",
#    'type': 'Notice',
#    'abstract': "The Department of Labor (DOL) hereby announces the submission of the Wage Hour Division (WHD) sponsored information collection request (ICR) titled, ``Report of Construction Contractor's Wage Rates,'' to the Office of Management and Budget (OMB) for review and approval for continued use in accordance with the Paperwork Reduction Act of 1995 (Pub. L. 104-13, 44 U.S.C. chapter 35).",
#    'document_number': '2011-1855',
#    'html_url': 'https://www.federalregister.gov/documents/2011/01/28/2011-1855/agency-information-collection-activities-submission-for-omb-review-comment-request-report-of',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2011-01-28/pdf/2011-1855.pdf',
#    'public_inspection_pdf_url': None,
#    'publication_date': '2011-01-28',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Office of the Secretary'}],
#    'excerpts': 'OMB approval for this information collection under OMB Control Number <span class="match">1235-0015</span>. The current OMB approval is scheduled to expire on January 11, 2011; however … appropriate consideration, comments should reference OMB Control Number <span class="match">1235-0015</span>. The OMB is particularly interested in comments that: \n • Evaluate whether … Report of Construction Contractor\'s Wage Rates. \n \n OMB Control Number: <span class="match">1235-0015</span>. \n \n Affected Public: Private sector—businesses or other for-profits. '},
#   {'title': 'Proposed Extension of the Approval of Information Collection Requirements',
#    'type': 'Notice',
#    'abstract': "The Department of Labor, as part of its continuing effort to reduce paperwork and respondent burden, conducts a preclearance consultation program to provide the general public and Federal agencies with an opportunity to comment on proposed and/or continuing collections of information in accordance with the Paperwork Reduction Act of 1995 (PRA95). 44 U.S.C. 3506(c)(2)(A). This program helps to ensure that requested data can be provided in the desired format, reporting burden (time and financial resources) is minimized, collection instruments are clearly understood, and the impact of collection requirements on respondents can be properly assessed. Currently, the Wage and Hour Division is soliciting comments concerning its proposal to extend Office of Management and Budget (OMB) approval of the Information Collection: Report of Construction Contractor's Wage Rates. A copy of the proposed information collection request can be obtained by contacting the office listed below in the FOR FURTHER INFORMATION CONTACT section of this Notice.",
#    'document_number': '2010-15401',
#    'html_url': 'https://www.federalregister.gov/documents/2010/06/25/2010-15401/proposed-extension-of-the-approval-of-information-collection-requirements',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2010-06-25/pdf/2010-15401.pdf',
#    'public_inspection_pdf_url': None,
#    'publication_date': '2010-06-25',
#    'agencies': [{'raw_name': 'DEPARTMENT OF LABOR',
#      'name': 'Labor Department',
#      'id': 271,
#      'url': 'https://www.federalregister.gov/agencies/labor-department',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/271',
#      'parent_id': None,
#      'slug': 'labor-department'},
#     {'raw_name': 'Wage and Hour Division',
#      'name': 'Wage and Hour Division',
#      'id': 524,
#      'url': 'https://www.federalregister.gov/agencies/wage-and-hour-division',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/524',
#      'parent_id': 271,
#      'slug': 'wage-and-hour-division'}],
#    'excerpts': '\n \n ADDRESSES: \n You may submit comments identified by Control Number <span class="match">1235-0015</span>, by either one of the following methods: \n \n E-mail: WHDPRAComments@dol … Title: Report of Construction Contractor\'s Wage Rates. \n \n OMB Numbers: <span class="match">1235-0015</span>. \n \n Affected Public: Businesses or other for-profits, Federal Government'}]}

# %%
fr_json['results'][0].keys()
# Out:
# dict_keys(['title', 'type', 'abstract', 'document_number', 'html_url', 'pdf_url', 'public_inspection_pdf_url', 'publication_date', 'agencies', 'excerpts'])

# %% [markdown]
# import json
#
# with open('data.txt') as json_file:
#     data = json.load(json_file)

# %%
os.listdir()
# Out:
# ['notices_1235-0029.json',
#  'notices_1205-0132.json',
#  'notices_1218-0096.json',
#  'notices_1220-0039.json',
#  'notices_1218-0061.json',
#  'notices_1225-0087.json',
#  'notices_1218-0070.json',
#  'notices_1205-0223.json',
#  'notices_1205-0519.json',
#  'notices_1220-0168.json',
#  'notices_1218-0270.json',
#  'notices_1205-0542.json',
#  'notices_1240-0031.json',
#  'notices_1218-0130.json',
#  'notices_1205-0522.json',
#  'notices_1205-0536.json',
#  'notices_1235-0015.json',
#  'notices_1240-0044.json',
#  'notices_1210-0131.json',
#  'notices_1210-0076.json',
#  'notices_1218-0180.json',
#  'notices_1219-0024.json',
#  'notices_1218-0215.json',
#  'notices_1218-0200.json',
#  'notices_1205-0453.json',
#  'notices_1219-0121.json',
#  'notices_1219-0095.json',
#  'notices_1205-0464.json',
#  'notices_1218-0067.json',
#  'notices_1218-0259.json',
#  'notices_1218-0189.json',
#  'notices_1240-0040.json',
#  'notices_4040-0007.json',
#  'notices_1220-0008.json',
#  'notices_1220-0042.json',
#  'notices_1293-0009.json',
#  'notices_1219-0019.json',
#  'notices_1250-0001.json',
#  'notices_1210-0100.json',
#  'notices_1293-0014.json',
#  'notices_1290-0002.json',
#  'notices_1218-0069.json',
#  'notices_1220-0017.json',
#  'notices_1210-0142.json',
#  'notices_1205-0025.json',
#  'notices_1240-0051.json',
#  'notices_1218-0099.json',
#  'notices_1210-0116.json',
#  'notices_1290-0018.json',
#  'notices_1293-0002.json',
#  'notices_1230-0014.json',
#  'notices_1218-0176.json',
#  'notices_1220-0011.json',
#  'notices_1205-0540.json',
#  'notices_1240-0029.json',
#  'notices_1219-0133.json',
#  'notices_1218-0252.json',
#  'notices_1205-0033.json',
#  'notices_1205-0177.json',
#  'notices_1205-0512.json',
#  'notices_1205-0417.json',
#  'notices_1218-0225.json',
#  'notices_1245-0003.json',
#  'notices_1240-0015.json',
#  'notices_1218-0184.json',
#  'notices_1219-0040.json',
#  'notices_1240-0048.json',
#  'notices_1220-0133.json',
#  'notices_1205-0150.json',
#  '.ipynb_checkpoints',
#  'notices_1210-0066.json',
#  'notices_1218-0085.json',
#  'notices_1205-0222.json',
#  'notices_1210-0122.json',
#  'notices_1220-0197.json',
#  'notices_1219-0051.json',
#  'notices_1210-0110.json',
#  'notices_1205-0499.json',
#  'notices_1210-0082.json',
#  'notices_1218-0271.json',
#  'notices_1219-0026.json',
#  'notices_1293-0005.json',
#  'notices_1218-0072.json',
#  'notices_1290-0016.json',
#  'notices_1219-0142.json',
#  'notices_1210-0058.json',
#  'notices_1218-0075.json',
#  'notices_1210-0089.json',
#  'notices_1218-0095.json',
#  'notices_1218-0222.json',
#  'notices_1240-0030.json',
#  'notices_1218-0269.json',
#  'notices_1210-0114.json',
#  'notices_1240-0055.json',
#  'notices_1205-0528.json',
#  'notices_1210-0138.json',
#  'notices_1218-0195.json',
#  'notices_1290-0025.json',
#  'notices_1220-0100.json',
#  'notices_1219-0146.json',
#  'notices_1210-0115.json',
#  'notices_1205-0187.json',
#  'notices_1219-0082.json',
#  'notices_1240-0018.json',
#  'notices_1219-0124.json',
#  'notices_1240-0021.json',
#  'notices_1205-0426.json',
#  'notices_1218-0233.json',
#  'notices_1210-0065.json',
#  'notices_1219-0089.json',
#  'notices_1205-0436.json',
#  'notices_1205-0009.json',
#  'notices_1218-0219.json',
#  'notices_1220-0186.json',
#  'notices_1205-0029.json',
#  'notices_1219-0152.json',
#  'notices_1235-0007.json',
#  'notices_1205-0421.json',
#  'notices_1205-0207.json',
#  'notices_4040-0013.json',
#  'notices_1205-0359.json',
#  'notices_1235-0016.json',
#  'notices_1205-0456.json',
#  'notices_1220-0050.json',
#  'notices_1218-0202.json',
#  'notices_1205-0457.json',
#  'notices_1219-0154.json',
#  'notices_1210-0034.json',
#  'notices_1220-0157.json',
#  'notices_1220-0134.json',
#  'notices_1218-0010.json',
#  'notices_1290-0020.json',
#  'notices_1210-0101.json',
#  'notices_1205-0137.json',
#  'notices_1219-0065.json',
#  'notices_1218-0198.json',
#  'notices_1218-0183.json',
#  'notices_1218-0274.json',
#  'notices_1205-0484.json',
#  'notices_1210-0134.json',
#  'notices_1218-0231.json',
#  'notices_1218-0103.json',
#  'notices_1219-0020.json',
#  'notices_1218-0121.json',
#  'notices_1240-0009.json',
#  'notices_1205-0531.json',
#  'notices_1240-0008.json',
#  'notices_1218-0203.json',
#  'notices_1240-0032.json',
#  'notices_1220-0163.json',
#  'notices_1205-0001.json',
#  'notices_1240-0053.json',
#  'notices_1235-0013.json',
#  'notices_1290-0012.json',
#  'notices_1205-0353.json',
#  'notices_1210-0147.json',
#  'notices_1205-0490.json',
#  'notices_1240-0005.json',
#  'notices_1235-0005.json',
#  'notices_1250-0011.json',
#  'notices_1210-0125.json',
#  'notices_1210-0126.json',
#  'notices_1210-0119.json',
#  'notices_1218-0147.json',
#  'notices_1225-0077.json',
#  'notices_1218-0224.json',
#  'notices_1240-0022.json',
#  'notices_1293-0015.json',
#  'notices_1220-0079.json',
#  'notices_1290-0024.json',
#  'notices_1218-0248.json',
#  'notices_1290-0015.json',
#  'notices_1218-0108.json',
#  'notices_1218-0260.json',
#  'notices_1219-0140.json',
#  'notices_1205-0275.json',
#  'notices_1218-0172.json',
#  'notices_1240-0038.json',
#  'notices_1205-0439.json',
#  'notices_1218-0197.json',
#  'notices_1210-0098.json',
#  'notices_1240-0035.json',
#  'notices_1218-0253.json',
#  'notices_1240-0007.json',
#  'notices_1240-0002.json',
#  'notices_1205-0219.json',
#  'notices_1218-0129.json',
#  'notices_1218-0247.json',
#  'notices_1220-0012.json',
#  'notices_1205-0509.json',
#  'notices_1250-0005.json',
#  'notices_1210-0063.json',
#  'notices_1219-0119.json',
#  'notices_1220-0141.json',
#  'notices_1205-0040.json',
#  'notices_1218-0229.json',
#  'notices_1218-0237.json',
#  'notices_1205-0154.json',
#  'notices_1218-0238.json',
#  'notices_1205-0432.json',
#  'notices_1205-0030.json',
#  'notices_1218-0221.json',
#  'notices_1218-0150.json',
#  'notices_1240-0027.json',
#  'notices_1218-0065.json',
#  'notices_1219-0042.json',
#  'notices_1210-0091.json',
#  'notices_1235-0024.json',
#  'notices_1205-0520.json',
#  'notices_1240-0037.json',
#  'notices_1218-0220.json',
#  'notices_1240-0049.json',
#  'notices_1240-0016.json',
#  'notices_1205-0508.json',
#  'notices_1218-0110.json',
#  'notices_1210-0161.json',
#  'notices_1240-0041.json',
#  'notices_1205-0431.json',
#  'notices_1218-0133.json',
#  'notices_1245-0004.json',
#  'notices_1205-0238.json',
#  'notices_1250-0002.json',
#  'notices_1220-0170.json',
#  'notices_1290-0029.json',
#  'notices_1240-0004.json',
#  'notices_1218-0199.json',
#  'notices_1220-0149.json',
#  'notices_1218-0003.json',
#  'notices_1290-0013.json',
#  'notices_1210-0128.json',
#  'notices_1218-0137.json',
#  'notices_1210-0090.json',
#  'notices_1240-0042.json',
#  'notices_1205-0010.json',
#  'notices_1219-0116.json',
#  'notices_1220-0109.json',
#  'notices_1235-0021.json',
#  'notices_1235-0018.json',
#  'notices_1240-0017.json',
#  'notices_1218-0143.json',
#  'notices_1250-0010.json',
#  'notices_1218-0128.json',
#  'notices_1220-0164.json',
#  'notices_1210-0150.json',
#  'notices_1210-0104.json',
#  'notices_1218-0048.json',
#  'notices_1219-0097.json',
#  'notices_1219-0041.json',
#  'notices_1290-0022.json',
#  'notices_1240-0036.json',
#  'notices_1210-0121.json',
#  'notices_1218-0207.json',
#  'notices_1240-0014.json',
#  'notices_1205-0539.json',
#  'notices_1210-0146.json',
#  'notices_1205-0164.json',
#  'notices_1210-0064.json',
#  'notices_1205-0513.json',
#  'notices_1240-0003.json',
#  'notices_1235-0008.json',
#  'notices_1219-0144.json',
#  'notices_1219-0007.json',
#  'notices_1210-0124.json',
#  'notices_1240-0023.json',
#  'notices_1205-0466.json',
#  'notices_1205-0507.json',
#  'notices_1219-0120.json',
#  'notices_1218-0258.json',
#  'notices_1220-0045.json',
#  'notices_1240-0045.json',
#  'notices_1218-0185.json',
#  'notices_1218-0265.json',
#  'notices_1240-0011.json',
#  'notices_1220-0196.json',
#  'notices_1210-0137.json',
#  'notices_1220-0192.json',
#  'notices_1218-0228.json',
#  'notices_1210-0040.json',
#  'notices_1205-0224.json',
#  'pending_eda.ipynb',
#  'notices_1219-0141.json',
#  'notices_1219-0103.json',
#  'notices_1240-0047.json',
#  'notices_1250-0004.json',
#  'notices_1219-0147.json',
#  'notices_1210-0149.json',
#  'notices_1220-0179.json',
#  'notices_1205-0517.json',
#  'notices_1210-0153.json',
#  'notices_1205-0541.json',
#  'notices_1219-0009.json',
#  'notices_1225-0088.json',
#  'notices_1205-0332.json',
#  'notices_1210-0140.json',
#  'notices_1219-0016.json',
#  'notices_1250-0003.json',
#  'notices_1218-0131.json',
#  'notices_1220-0175.json',
#  'notices_1218-0217.json',
#  'notices_1210-0132.json',
#  'notices_1205-0310.json',
#  'notices_1210-0144.json',
#  'notices_1219-0150.json',
#  'notices_1210-0039.json',
#  'notices_1240-0028.json',
#  'notices_1210-0112.json',
#  'notices_1205-0342.json',
#  'notices_1218-0230.json',
#  'notices_1210-0123.json',
#  'notices_1290-0021.json',
#  'notices_1210-0083.json',
#  'notices_1219-0135.json',
#  'notices_1240-0054.json',
#  'notices_1205-0039.json',
#  'notices_1218-0267.json',
#  'notices_1210-0141.json',
#  'notices_1205-0530.json',
#  'notices_1218-0208.json',
#  'notices_1212-0017.json',
#  'notices_1210-0061.json',
#  'notices_4040-0010.json',
#  'notices_1210-0049.json',
#  'notices_1219-0004.json',
#  'notices_1210-0085.json',
#  'notices_1218-0126.json',
#  'notices_1219-0054.json',
#  'notices_1245-0006.json',
#  'notices_1240-0033.json',
#  'notices_1219-0083.json',
#  'notices_1210-0160.json',
#  'notices_1210-0136.json',
#  'notices_1218-0196.json',
#  'notices_1218-0101.json',
#  'notices_1235-0006.json',
#  'notices_1205-0455.json',
#  'notices_1240-0057.json',
#  'notices_1225-0059.json',
#  'notices_1240-0010.json',
#  'notices_1218-0134.json',
#  'notices_1218-0206.json',
#  'notices_1218-0205.json',
#  'notices_1218-0218.json',
#  'notices_1240-0001.json',
#  'notices_1219-0088.json',
#  'notices_1210-0059.json',
#  'notices_1240-0046.json',
#  'notices_1205-0051.json',
#  'notices_1205-0538.json',
#  'notices_1205-0199.json',
#  'notices_1220-0194.json',
#  'notices_1218-0255.json',
#  'notices_1210-0133.json',
#  'notices_1218-0266.json',
#  'notices_1218-0104.json',
#  'notices_1205-0162.json',
#  'notices_1210-0095.json',
#  'notices_1240-0019.json',
#  'notices_1290-0027.json',
#  'notices_1240-0034.json',
#  'notices_1240-0012.json',
#  'notices_1235-0023.json',
#  'notices_1218-0244.json',
#  'notices_1205-0422.json',
#  'notices_1218-0186.json',
#  'notices_1290-0017.json',
#  'notices_1240-0024.json',
#  'notices_1225-0086.json',
#  'notices_4040-0006.json',
#  'notices_1218-0226.json',
#  'notices_1219-0003.json',
#  'notices_1218-0170.json',
#  'notices_1219-0148.json',
#  'notices_1240-0025.json',
#  'notices_1219-0034.json',
#  'notices_1205-0535.json',
#  'notices_1205-0543.json',
#  'notices_1225-0013.json',
#  'notices_1220-0180.json',
#  'notices_1240-0013.json',
#  'notices_1205-0176.json',
#  'notices_1210-0048.json',
#  'notices_1219-0015.json',
#  'notices_1205-0179.json',
#  'notices_1205-0523.json',
#  'notices_1240-0026.json',
#  'notices_1218-0241.json',
#  'notices_1205-0489.json',
#  'notices_1219-0151.json',
#  'notices_1210-0145.json',
#  'notices_1220-0044.json',
#  'notices_1218-0223.json',
#  'notices_1210-0060.json',
#  'notices_1218-0242.json',
#  'notices_1205-0268.json',
#  'notices_1219-0073.json',
#  'history_eda.ipynb',
#  'notices_1290-0014.json',
#  'notices_1235-0032.json',
#  'notices_1218-0011.json',
#  'notices_1218-0261.json',
#  'notices_1218-0216.json',
#  'notices_1205-0430.json',
#  'notices_1219-0025.json',
#  'notices_1218-0239.json',
#  'notices_1218-0236.json',
#  'notices_1219-0096.json',
#  'notices_1205-0392.json',
#  'notices_1290-0031.json',
#  'notices_1205-0017.json',
#  'notices_1210-0117.json',
#  'notices_1219-0048.json',
#  'notices_1235-0002.json',
#  'notices_1235-0031.json',
#  'notices_1218-0100.json',
#  'notices_1210-0127.json',
#  'notices_1290-0028.json',
#  'notices_1219-0143.json',
#  'notices_1218-0092.json',
#  'notices_1290-0030.json',
#  'notices_1205-0526.json',
#  'notices_1220-0189.json',
#  'notices_1210-0111.json',
#  'notices_1219-0131.json',
#  'notices_1250-0006.json',
#  'notices_1218-0262.json',
#  'notices_1219-0049.json',
#  'notices_1220-0025.json',
#  'notices_1205-0451.json',
#  'notices_4040-0004.json',
#  'notices_1210-0118.json',
#  'notices_1240-0058.json',
#  'notices_1210-0053.json',
#  'notices_1219-0066.json',
#  'notices_1290-0019.json',
#  'notices_1205-0510.json',
#  'notices_1205-0015.json',
#  'notices_1205-0534.json',
#  'notices_1205-0035.json',
#  'notices_1205-0028.json',
#  'notices_1205-0527.json',
#  'notices_1219-0078.json',
#  'notices_1219-0138.json',
#  'notices_1219-0011.json',
#  'notices_1220-0195.json',
#  'notices_1219-0001.json',
#  'notices_1219-0014.json',
#  'notices_1290-0023.json',
#  'notices_1205-0245.json',
#  'notices_1205-0178.json',
#  'notices_1235-0001.json',
#  'notices_1218-0145.json',
#  'notices_1290-0026.json',
#  'notices_1205-0172.json',
#  'notices_1240-0020.json',
#  'notices_1220-0104.json',
#  'notices_1218-0093.json',
#  'notices_1210-0113.json',
#  'notices_1220-0102.json',
#  'notices_1210-0094.json',
#  'notices_1205-0448.json',
#  'connect_to_postgres_database_and_add_a_df_as_table.ipynb',
#  'notices_1219-0046.json',
#  'notices_1205-0461.json',
#  'notices_1205-0371.json',
#  'notices_1219-0127.json',
#  'notices_1210-0084.json',
#  'notices_1218-0064.json',
#  'notices_1210-0092.json',
#  'notices_1205-0134.json',
#  'notices_1240-0059.json',
#  'notices_1240-0006.json',
#  'todo_for_open_loop_report.ipynb',
#  'notices_1212-0009.json',
#  'notices_1210-0148.json',
#  'notices_1240-0039.json',
#  'notices_1210-0158.json',
#  'notices_1205-0521.json',
#  'notices_1219-0030.json',
#  'notices_1240-0050.json',
#  'notices_3046-0046.json',
#  'notices_1220-0032.json',
#  'notices_1210-0130.json',
#  'notice_2020-07-28',
#  'notices_1218-0179.json',
#  'notices_1219-0039.json',
#  'notices_1235-0003.json']

# %%
file='notices_1235-0029.json'

# %%
file[8:17]
# Out:
# '1235-0029'

# %%
with open(file) as json_file:
    data = json.load(json_file)

# %%
data['results'][0].keys()
# Out:
# dict_keys(['title', 'type', 'abstract', 'document_number', 'html_url', 'pdf_url', 'public_inspection_pdf_url', 'publication_date', 'agencies', 'excerpts'])

# %%
data['results'][0]['title']
# Out:
# 'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Establishing Paid Sick Leave for Federal Contractors'

# %%
rows = []

for file in os.listdir():
    with open(file) as json_file:
        data = json.load(json_file)
        if data['count'] > 0:
            notice=data['results'][0]
            row = [file[8:17],notice['title'],notice['document_number'],notice['html_url'],notice['publication_date']]
            rows.append(row)
        else:
            row = [file[8:17],'problem','problem','problem','problem']
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-43-182712f6b6a2> in <module>
#       2
#       3 for file in os.listdir():
# ----> 4     with open(file) as json_file:
#       5         data = json.load(json_file)
#       6         if data['count'] > 0:
#
# IsADirectoryError: [Errno 21] Is a directory: '.ipynb_checkpoints'

# %%
file_list =os.listdir()

# %%
file_list.remove('.ipynb_checkpoints')

# %%
rows = []

for file in file_list:
    with open(file) as json_file:
        data = json.load(json_file)
        if data['count'] > 0:
            notice=data['results'][0]
            row = [file[8:17],notice['title'],notice['document_number'],notice['html_url'],notice['publication_date']]
            rows.append(row)
        else:
            row = [file[8:17],'problem','problem','problem','problem']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-cf8fac714e93> in <module>
#       4     with open(file) as json_file:
#       5         data = json.load(json_file)
# ----> 6         if data['count'] > 0:
#       7             notice=data['results'][0]
#       8             row = [file[8:17],notice['title'],notice['document_number'],notice['html_url'],notice['publication_date']]
#
# KeyError: 'count'

# %%
rows
# Out:
# [['1235-0029',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Establishing Paid Sick Leave for Federal Contractors',
#   '2019-27332',
#   'https://www.federalregister.gov/documents/2019/12/19/2019-27332/agency-information-collection-activities-submission-for-omb-review-comment-request-establishing-paid',
#   '2019-12-19'],
#  ['1205-0132',
#   'Agency Information Collection Activities; Comment Request; Unemployment Insurance (UI) State Quality Service Plan (SQSP) Planning and Reporting Guidelines',
#   '2020-09061',
#   'https://www.federalregister.gov/documents/2020/04/29/2020-09061/agency-information-collection-activities-comment-request-unemployment-insurance-ui-state-quality',
#   '2020-04-29'],
#  ['1218-0096',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1220-0039',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Consumer Price Index Commodities and Services Survey',
#   '2020-15595',
#   'https://www.federalregister.gov/documents/2020/07/21/2020-15595/agency-information-collection-activities-submission-for-omb-review-comment-request-consumer-price',
#   '2020-07-21'],
#  ['1218-0061',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23295',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23295/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1225-0087',
#   'Agency Information Collection Activities; Comment Request; Application for Use of Public Space by Non-DOL Agencies in the Frances Perkins Building',
#   '2020-13056',
#   'https://www.federalregister.gov/documents/2020/06/17/2020-13056/agency-information-collection-activities-comment-request-application-for-use-of-public-space-by',
#   '2020-06-17'],
#  ['1218-0070',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1205-0223',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Labor Standards for the Registration of Apprenticeship Program',
#   '2020-01618',
#   'https://www.federalregister.gov/documents/2020/01/30/2020-01618/agency-information-collection-activities-submission-for-omb-review-comment-request-labor-standards',
#   '2020-01-30'],
#  ['1205-0519',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; H-2A Sheepherder Recordkeeping Requirement',
#   '2018-26110',
#   'https://www.federalregister.gov/documents/2018/12/03/2018-26110/agency-information-collection-activities-submission-for-omb-review-comment-request-h-2a-sheepherder',
#   '2018-12-03'],
#  ['1220-0168',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; General Inquiries to State Agency Contacts',
#   '2018-06494',
#   'https://www.federalregister.gov/documents/2018/03/30/2018-06494/agency-information-collection-activities-submission-for-omb-review-comment-request-general-inquiries',
#   '2018-03-30'],
#  ['1218-0270',
#   "Cranes and Derricks in Construction; Extension of the Office of Management and Budget's (OMB) Approval of Information Collection (Paperwork) Requirements",
#   '2020-03787',
#   'https://www.federalregister.gov/documents/2020/02/26/2020-03787/cranes-and-derricks-in-construction-extension-of-the-office-of-management-and-budgets-omb-approval',
#   '2020-02-26'],
#  ['1240-0031',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Certification by School Official',
#   '2020-02002',
#   'https://www.federalregister.gov/documents/2020/02/03/2020-02002/agency-information-collection-activities-submission-for-omb-review-comment-request-certification-by',
#   '2020-02-03'],
#  ['1218-0130',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1205-0522',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Required Elements for Submission of the Unified or Combined State Plan and Plan Modifications Under the Workforce Innovation and Opportunity Act',
#   '2019-16254',
#   'https://www.federalregister.gov/documents/2019/07/31/2019-16254/agency-information-collection-activities-submission-for-omb-review-comment-request-required-elements',
#   '2019-07-31'],
#  ['1235-0015',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Report of Construction Contractor's Wage Rates",
#   '2020-11458',
#   'https://www.federalregister.gov/documents/2020/05/28/2020-11458/agency-information-collection-activities-submission-for-omb-review-comment-request-report-of',
#   '2020-05-28'],
#  ['1240-0044',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Health Insurance Claim Form',
#   '2016-03985',
#   'https://www.federalregister.gov/documents/2016/02/25/2016-03985/agency-information-collection-activities-submission-for-omb-review-comment-request-health-insurance',
#   '2016-02-25'],
#  ['1210-0131',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Access to Multiemployer Plan Information',
#   '2019-18338',
#   'https://www.federalregister.gov/documents/2019/08/27/2019-18338/agency-information-collection-activities-submission-for-omb-review-comment-request-access-to',
#   '2019-08-27'],
#  ['1210-0076',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Loans To Plan Participants and Beneficiaries Who Are Parties in Interest With Respect to the Plan Regulation',
#   '2020-10826',
#   'https://www.federalregister.gov/documents/2020/05/20/2020-10826/agency-information-collection-activities-submission-for-omb-review-comment-request-loans-to-plan',
#   '2020-05-20'],
#  ['1218-0180',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23295',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23295/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1219-0024',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Application for Waiver of Surface Sanitary Facilities' Requirements (Pertaining to Coal Mines)",
#   '2020-05607',
#   'https://www.federalregister.gov/documents/2020/03/18/2020-05607/agency-information-collection-activities-submission-for-omb-review-comment-request-application-for',
#   '2020-03-18'],
#  ['1218-0215',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1218-0200',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2020-12631',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12631/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2020-06-11'],
#  ['1205-0453',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; National Agricultural Workers Survey',
#   '2019-25253',
#   'https://www.federalregister.gov/documents/2019/11/21/2019-25253/agency-information-collection-activities-submission-for-omb-review-comment-request-national',
#   '2019-11-21'],
#  ['1219-0121',
#   'Proposed Extension of Information Collection; Safety Standards for Roof Bolts in Metal and Nonmetal Mines and Underground Coal Mines',
#   '2018-15216',
#   'https://www.federalregister.gov/documents/2018/07/17/2018-15216/proposed-extension-of-information-collection-safety-standards-for-roof-bolts-in-metal-and-nonmetal',
#   '2018-07-17'],
#  ['1219-0095',
#   'Proposed Extension of Information Collection; Explosive Materials and Blasting Units',
#   '2018-23418',
#   'https://www.federalregister.gov/documents/2018/10/26/2018-23418/proposed-extension-of-information-collection-explosive-materials-and-blasting-units',
#   '2018-10-26'],
#  ['1205-0464',
#   'Agency Information Collection Activities; Comment Request; YouthBuild (YB) Reporting System',
#   '2018-01333',
#   'https://www.federalregister.gov/documents/2018/01/26/2018-01333/agency-information-collection-activities-comment-request-youthbuild-yb-reporting-system',
#   '2018-01-26'],
#  ['1218-0067',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-00391',
#   'https://www.federalregister.gov/documents/2018/01/12/2018-00391/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-01-12'],
#  ['1218-0259',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1218-0189',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23295',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23295/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1240-0040',
#   'Agency Information Collection Activities; Comment Request; Certification of Funeral Expenses',
#   '2020-07470',
#   'https://www.federalregister.gov/documents/2020/04/09/2020-07470/agency-information-collection-activities-comment-request-certification-of-funeral-expenses',
#   '2020-04-09'],
#  ['4040-0007',
#   'Brookwood-Sago Mine Safety Grants',
#   '2019-05594',
#   'https://www.federalregister.gov/documents/2019/03/25/2019-05594/brookwood-sago-mine-safety-grants',
#   '2019-03-25'],
#  ['1220-0008',
#   'Proposed Collection; Comment Request',
#   '2020-12199',
#   'https://www.federalregister.gov/documents/2020/06/05/2020-12199/proposed-collection-comment-request',
#   '2020-06-05'],
#  ['1220-0042',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Report on Occupational Employment and Wages',
#   '2020-04802',
#   'https://www.federalregister.gov/documents/2020/03/10/2020-04802/agency-information-collection-activities-submission-for-omb-review-comment-request-report-on',
#   '2020-03-10'],
#  ['1293-0009',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Jobs for Veterans State Grants Reports',
#   '2019-19355',
#   'https://www.federalregister.gov/documents/2019/09/09/2019-19355/agency-information-collection-activities-submission-for-omb-review-comment-request-jobs-for-veterans',
#   '2019-09-09'],
#  ['1219-0019',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Slope and Shaft Sinking Plans (Pertains to Surface Work Areas of Underground Coal Mines)',
#   '2020-05614',
#   'https://www.federalregister.gov/documents/2020/03/18/2020-05614/agency-information-collection-activities-submission-for-omb-review-comment-request-slope-and-shaft',
#   '2020-03-18'],
#  ['1250-0001',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Office of Federal Contract Compliance Programs Construction Recordkeeping and Reporting Requirements',
#   '2018-07288',
#   'https://www.federalregister.gov/documents/2018/04/10/2018-07288/agency-information-collection-activities-submission-for-omb-review-comment-request-office-of-federal',
#   '2018-04-10'],
#  ['1210-0100',
#   'Proposed Extension of Information Collection Requests for Public Comment',
#   '2018-23079',
#   'https://www.federalregister.gov/documents/2018/10/23/2018-23079/proposed-extension-of-information-collection-requests-for-public-comment',
#   '2018-10-23'],
#  ['1293-0014',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Veterans' Employment and Training Service Competitive Grant Programs Reporting",
#   '2020-07468',
#   'https://www.federalregister.gov/documents/2020/04/09/2020-07468/agency-information-collection-activities-submission-for-omb-review-comment-request-veterans',
#   '2020-04-09'],
#  ['1290-0002',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Department of Labor Events Registration Platform',
#   '2017-23992',
#   'https://www.federalregister.gov/documents/2017/11/03/2017-23992/agency-information-collection-activities-submission-for-omb-review-comment-request-department-of',
#   '2017-11-03'],
#  ['1218-0069',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1220-0017',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Local Area Unemployment Statistics Program',
#   '2018-08531',
#   'https://www.federalregister.gov/documents/2018/04/24/2018-08531/agency-information-collection-activities-submission-for-omb-review-comment-request-local-area',
#   '2018-04-24'],
#  ['1210-0142',
#   'Proposed Extension of Information Collection Requests for Public Comment',
#   '2018-23079',
#   'https://www.federalregister.gov/documents/2018/10/23/2018-23079/proposed-extension-of-information-collection-requests-for-public-comment',
#   '2018-10-23'],
#  ['1205-0025',
#   'Agency Information Collection Activities; Comment Request; Job Corps Application Data',
#   '2020-00064',
#   'https://www.federalregister.gov/documents/2020/01/08/2020-00064/agency-information-collection-activities-comment-request-job-corps-application-data',
#   '2020-01-08'],
#  ['1240-0051',
#   'Proposed Extension of Existing Collection; Comment Request',
#   '2019-00614',
#   'https://www.federalregister.gov/documents/2019/02/01/2019-00614/proposed-extension-of-existing-collection-comment-request',
#   '2019-02-01'],
#  ['1218-0099',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1210-0116',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Annual Report for Multiple Employer Welfare Arrangements',
#   '2019-13805',
#   'https://www.federalregister.gov/documents/2019/06/28/2019-13805/agency-information-collection-activities-submission-for-omb-review-comment-request-annual-report-for',
#   '2019-06-28'],
#  ['1293-0002',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; VETS/USERRA/VP (VETS-1010 Form)',
#   '2020-01624',
#   'https://www.federalregister.gov/documents/2020/01/30/2020-01624/agency-information-collection-activities-submission-for-omb-review-comment-request-vetsuserravp',
#   '2020-01-30'],
#  ['1218-0176',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1220-0011',
#   'Information Collection Activities; Comment Request',
#   '2020-15594',
#   'https://www.federalregister.gov/documents/2020/07/20/2020-15594/information-collection-activities-comment-request',
#   '2020-07-20'],
#  ['1240-0029',
#   'Agency Information Collection Activities; Comment Request; Request for Examination and/or Treatment',
#   '2020-12632',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12632/agency-information-collection-activities-comment-request-request-for-examination-andor-treatment',
#   '2020-06-11'],
#  ['1219-0133',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Hazard Communication Standard',
#   '2017-24994',
#   'https://www.federalregister.gov/documents/2017/11/17/2017-24994/agency-information-collection-activities-submission-for-omb-review-comment-request-hazard',
#   '2017-11-17'],
#  ['1218-0252',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Hexavalent Chromium Standards for General Industry, Shipyard Employment, and Construction',
#   '2020-01396',
#   'https://www.federalregister.gov/documents/2020/01/28/2020-01396/agency-information-collection-activities-submission-for-omb-review-comment-request-hexavalent',
#   '2020-01-28'],
#  ['1205-0033',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Job Corps Health Questionnaire',
#   '2020-09412',
#   'https://www.federalregister.gov/documents/2020/05/04/2020-09412/agency-information-collection-activities-submission-for-omb-review-comment-request-job-corps-health',
#   '2020-05-04'],
#  ['1205-0177',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Benefits Rights and Experience Report',
#   '2019-17085',
#   'https://www.federalregister.gov/documents/2019/08/09/2019-17085/agency-information-collection-activities-submission-for-omb-review-comment-request-benefits-rights',
#   '2019-08-09'],
#  ['1205-0512',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Registered Apprenticeship College Consortium',
#   '2020-11468',
#   'https://www.federalregister.gov/documents/2020/05/28/2020-11468/agency-information-collection-activities-submission-for-omb-review-comment-request-registered',
#   '2020-05-28'],
#  ['1205-0417',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Workforce Information Grants to States (WIGS)',
#   '2020-07951',
#   'https://www.federalregister.gov/documents/2020/04/15/2020-07951/agency-information-collection-activities-submission-for-omb-review-comment-request-workforce',
#   '2020-04-15'],
#  ['1218-0225',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1245-0003',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Labor Organization and Auxiliary Reports',
#   '2020-09178',
#   'https://www.federalregister.gov/documents/2020/04/30/2020-09178/agency-information-collection-activities-submission-for-omb-review-comment-request-labor',
#   '2020-04-30'],
#  ['1240-0015',
#   'Agency Information Collection Activities; Comment Request; Claim for Continuance of Compensation',
#   '2020-11471',
#   'https://www.federalregister.gov/documents/2020/05/28/2020-11471/agency-information-collection-activities-comment-request-claim-for-continuance-of-compensation',
#   '2020-05-28'],
#  ['1218-0184',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Standard on 4,4′-Methylenedianiline for General Industry',
#   '2020-01500',
#   'https://www.federalregister.gov/documents/2020/01/29/2020-01500/agency-information-collection-activities-submission-for-omb-review-comment-request-standard-on',
#   '2020-01-29'],
#  ['1219-0040',
#   'Proposed Extension of Information Collection; Independent Contractor Registration and Identification',
#   '2018-14089',
#   'https://www.federalregister.gov/documents/2018/07/02/2018-14089/proposed-extension-of-information-collection-independent-contractor-registration-and-identification',
#   '2018-07-02'],
#  ['1240-0048',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Notice of Issuance of Insurance Policy',
#   '2020-02305',
#   'https://www.federalregister.gov/documents/2020/02/06/2020-02305/agency-information-collection-activities-submission-for-omb-review-comment-request-notice-of',
#   '2020-02-06'],
#  ['1220-0133',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Census of Fatal Occupational Injuries',
#   '2019-21379',
#   'https://www.federalregister.gov/documents/2019/10/02/2019-21379/agency-information-collection-activities-submission-for-omb-review-comment-request-census-of-fatal',
#   '2019-10-02'],
#  ['1205-0150',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Nonmonetary Determination Activity Report',
#   '2020-09365',
#   'https://www.federalregister.gov/documents/2020/05/04/2020-09365/agency-information-collection-activities-submission-for-omb-review-comment-request-nonmonetary',
#   '2020-05-04'],
#  ['1210-0066',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1218-0085',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1205-0222',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Transmittal for Unemployment Insurance Materials',
#   '2019-18757',
#   'https://www.federalregister.gov/documents/2019/08/30/2019-18757/agency-information-collection-activities-submission-for-omb-review-comment-request-transmittal-for',
#   '2019-08-30'],
#  ['1210-0122',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1219-0051',
#   'Proposed Extension of Information Collection; Escape and Evacuation Plans for Surface Coal Mines, Surface Facilities and Surface Work Areas of Underground Coal Mines.',
#   '2018-23417',
#   'https://www.federalregister.gov/documents/2018/10/26/2018-23417/proposed-extension-of-information-collection-escape-and-evacuation-plans-for-surface-coal-mines',
#   '2018-10-26'],
#  ['1210-0110',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1205-0499',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Short-Time Compensation Grants',
#   '2019-13803',
#   'https://www.federalregister.gov/documents/2019/06/28/2019-13803/agency-information-collection-activities-submission-for-omb-review-comment-request-short-time',
#   '2019-06-28'],
#  ['1210-0082',
#   'Proposed Extension of Information Collection Requests for Public Comment',
#   '2018-23079',
#   'https://www.federalregister.gov/documents/2018/10/23/2018-23079/proposed-extension-of-information-collection-requests-for-public-comment',
#   '2018-10-23'],
#  ['1218-0271',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1219-0026',
#   'Proposed Extension of Information Collection; Ground Control for Surface Coal Mines and Surface Work Areas of Underground Coal Mines',
#   '2018-25963',
#   'https://www.federalregister.gov/documents/2018/11/29/2018-25963/proposed-extension-of-information-collection-ground-control-for-surface-coal-mines-and-surface-work',
#   '2018-11-29'],
#  ['1293-0005',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Federal Contractor Veterans' Employment Report",
#   '2017-26091',
#   'https://www.federalregister.gov/documents/2017/12/04/2017-26091/agency-information-collection-activities-submission-for-omb-review-comment-request-federal',
#   '2017-12-04'],
#  ['1218-0072',
#   "The Hazard Communication Standard; Extension of the Office of Management and Budget's Approval of Information Collection (Paperwork) Requirements",
#   '2020-15703',
#   'https://www.federalregister.gov/documents/2020/07/21/2020-15703/the-hazard-communication-standard-extension-of-the-office-of-management-and-budgets-approval-of',
#   '2020-07-21'],
#  ['1219-0142',
#   'Proposed Extension of Information Collection; Sealing of Abandoned Areas',
#   '2020-16133',
#   'https://www.federalregister.gov/documents/2020/07/27/2020-16133/proposed-extension-of-information-collection-sealing-of-abandoned-areas',
#   '2020-07-27'],
#  ['1210-0058',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Prohibited Transaction Class Exemptions for Multiple Employer Plans and Multiple Employer Apprenticeship Plans-PTE 1976-1, PTE 1977-10, PTE 1978-6',
#   '2019-10384',
#   'https://www.federalregister.gov/documents/2019/05/20/2019-10384/agency-information-collection-activities-submission-for-omb-review-comment-request-prohibited',
#   '2019-05-20'],
#  ['1218-0075',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1210-0089',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1218-0095',
#   "Concrete and Masonry Construction Standard; Extension of the Office of Management and Budget's (OMB) Approval of Information Collection (Paperwork) Requirements",
#   '2020-10828',
#   'https://www.federalregister.gov/documents/2020/05/20/2020-10828/concrete-and-masonry-construction-standard-extension-of-the-office-of-management-and-budgets-omb',
#   '2020-05-20'],
#  ['1218-0222',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Derricks Standard',
#   '2020-01505',
#   'https://www.federalregister.gov/documents/2020/01/29/2020-01505/agency-information-collection-activities-submission-for-omb-review-comment-request-derricks-standard',
#   '2020-01-29'],
#  ['1240-0030',
#   "Division of Coal Mine Workers' Compensation; Proposed Collection; Comment Request",
#   '2018-14095',
#   'https://www.federalregister.gov/documents/2018/06/29/2018-14095/division-of-coal-mine-workers-compensation-proposed-collection-comment-request',
#   '2018-06-29'],
#  ['1218-0269',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1210-0114',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1240-0055',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Authorization Request Forms/Certification/Letter of Medical Necessity',
#   '2020-02730',
#   'https://www.federalregister.gov/documents/2020/02/12/2020-02730/agency-information-collection-activities-submission-for-omb-review-comment-request-authorization',
#   '2020-02-12'],
#  ['1205-0528',
#   'Agency Information Collection Activities; Comment Request',
#   '2020-07937',
#   'https://www.federalregister.gov/documents/2020/04/15/2020-07937/agency-information-collection-activities-comment-request',
#   '2020-04-15'],
#  ['1210-0138',
#   'Proposed Extension of Information Collection Requests Submitted for Public Comment',
#   '2019-22126',
#   'https://www.federalregister.gov/documents/2019/10/10/2019-22126/proposed-extension-of-information-collection-requests-submitted-for-public-comment',
#   '2019-10-10'],
#  ['1218-0195',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Asbestos in Shipyards Standard',
#   '2020-08039',
#   'https://www.federalregister.gov/documents/2020/04/16/2020-08039/agency-information-collection-activities-submission-for-omb-review-comment-request-asbestos-in',
#   '2020-04-16'],
#  ['1220-0100',
#   'Information Collection Activities; Comment Request',
#   '2020-10561',
#   'https://www.federalregister.gov/documents/2020/05/18/2020-10561/information-collection-activities-comment-request',
#   '2020-05-18'],
#  ['1219-0146',
#   'Proposed Extension of Information Collection; Refuge Alternatives for Underground Coal Mines',
#   '2018-14091',
#   'https://www.federalregister.gov/documents/2018/07/02/2018-14091/proposed-extension-of-information-collection-refuge-alternatives-for-underground-coal-mines',
#   '2018-07-02'],
#  ['1210-0115',
#   'Proposed Extension of Information Collection Requests Submitted for Public Comment',
#   '2018-07459',
#   'https://www.federalregister.gov/documents/2018/04/11/2018-07459/proposed-extension-of-information-collection-requests-submitted-for-public-comment',
#   '2018-04-11'],
#  ['1205-0187',
#   'Agency Information Collection Activities; Comment Request; Overpayment Detection and Recovery Activities',
#   '2020-02181',
#   'https://www.federalregister.gov/documents/2020/02/05/2020-02181/agency-information-collection-activities-comment-request-overpayment-detection-and-recovery',
#   '2020-02-05'],
#  ['1219-0082',
#   'Proposed Extension of Information Collection; Records of Preshift and Onshift Inspections of Slope and Shaft Areas of Slope and Shaft Sinking Operations at Coal Mines',
#   '2018-25633',
#   'https://www.federalregister.gov/documents/2018/11/26/2018-25633/proposed-extension-of-information-collection-records-of-preshift-and-onshift-inspections-of-slope',
#   '2018-11-26'],
#  ['1240-0018',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Claim for Reimbursement-Assisted Reemployment',
#   '2019-20746',
#   'https://www.federalregister.gov/documents/2019/09/25/2019-20746/agency-information-collection-activities-submission-for-omb-review-comment-request-claim-for',
#   '2019-09-25'],
#  ['1219-0124',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Health Standards for Diesel Particulate Matter Exposure (Underground Coal Mines)',
#   '2020-07466',
#   'https://www.federalregister.gov/documents/2020/04/09/2020-07466/agency-information-collection-activities-submission-for-omb-review-comment-request-health-standards',
#   '2020-04-09'],
#  ['1240-0021',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Provider Enrollment Form',
#   '2020-02961',
#   'https://www.federalregister.gov/documents/2020/02/14/2020-02961/agency-information-collection-activities-submission-for-omb-review-comment-request-provider',
#   '2020-02-14'],
#  ['1205-0426',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Post Enrollment Data Collection for Job Corps Participants',
#   '2019-23298',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23298/agency-information-collection-activities-submission-for-omb-review-comment-request-post-enrollment',
#   '2019-10-25'],
#  ['1218-0233',
#   "Rigging Equipment for Material Handling; Extension of the Office of Management and Budget's (OMB) Approval of Information Collection (Paperwork) Requirements",
#   '2020-13520',
#   'https://www.federalregister.gov/documents/2020/06/24/2020-13520/rigging-equipment-for-material-handling-extension-of-the-office-of-management-and-budgets-omb',
#   '2020-06-24'],
#  ['1210-0065',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Securities Lending by Employee Benefits Plans, Prohibited Transaction Exemption 2006-16',
#   '2019-17830',
#   'https://www.federalregister.gov/documents/2019/08/20/2019-17830/agency-information-collection-activities-submission-for-omb-review-comment-request-securities',
#   '2019-08-20'],
#  ['1219-0089',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Safety Defects; Examination, Correction, and Records',
#   '2020-13488',
#   'https://www.federalregister.gov/documents/2020/06/23/2020-13488/agency-information-collection-activities-submission-for-omb-review-comment-request-safety-defects',
#   '2020-06-23'],
#  ['1205-0436',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Employment and Training Administration Quick Turnaround Surveys',
#   '2020-08899',
#   'https://www.federalregister.gov/documents/2020/04/28/2020-08899/agency-information-collection-activities-submission-for-omb-review-comment-request-employment-and',
#   '2020-04-28'],
#  ['1205-0009',
#   'Agency Information Collection Activities; Comment Request; Distribution of Characteristics of the Insured Unemployed',
#   '2018-16215',
#   'https://www.federalregister.gov/documents/2018/07/30/2018-16215/agency-information-collection-activities-comment-request-distribution-of-characteristics-of-the',
#   '2018-07-30'],
#  ['1218-0219',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1220-0186',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Current Population Survey Disability Supplement',
#   '2019-11097',
#   'https://www.federalregister.gov/documents/2019/05/29/2019-11097/agency-information-collection-activities-submission-for-omb-review-comment-request-current',
#   '2019-05-29'],
#  ['1205-0029',
#   'Agency Information Collection Activities; Comment Request; Interstate Arrangement for Combining Employment and Wages',
#   '2020-01626',
#   'https://www.federalregister.gov/documents/2020/01/30/2020-01626/agency-information-collection-activities-comment-request-interstate-arrangement-for-combining',
#   '2020-01-30'],
#  ['1219-0152',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Periodic Medical Surveillance Examinations for Coal Miners',
#   '2020-15373',
#   'https://www.federalregister.gov/documents/2020/07/17/2020-15373/agency-information-collection-activities-submission-for-omb-review-comment-request-periodic-medical',
#   '2020-07-17'],
#  ['1235-0007',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Labor Standards for Federal Service Contracts-Regulations 29 CFR Part 4',
#   '2019-27408',
#   'https://www.federalregister.gov/documents/2019/12/19/2019-27408/agency-information-collection-activities-submission-for-omb-review-comment-request-labor-standards',
#   '2019-12-19'],
#  ['1205-0421',
#   'Agency Information Collection Activities; Comment Request; O*NET Data Collection Program',
#   '2018-06414',
#   'https://www.federalregister.gov/documents/2018/03/30/2018-06414/agency-information-collection-activities-comment-request-onet-data-collection-program',
#   '2018-03-30'],
#  ['1205-0207',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Petition for Classifying Labor Surplus Areas',
#   '2020-07949',
#   'https://www.federalregister.gov/documents/2020/04/15/2020-07949/agency-information-collection-activities-submission-for-omb-review-comment-request-petition-for',
#   '2020-04-15'],
#  ['4040-0013',
#   'Brookwood-Sago Mine Safety Grants',
#   '2019-05594',
#   'https://www.federalregister.gov/documents/2019/03/25/2019-05594/brookwood-sago-mine-safety-grants',
#   '2019-03-25'],
#  ['1205-0359',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Benefits Timeliness and Quality Review System',
#   '2020-09366',
#   'https://www.federalregister.gov/documents/2020/05/04/2020-09366/agency-information-collection-activities-submission-for-omb-review-comment-request-benefits',
#   '2020-05-04'],
#  ['1235-0016',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2020-03606',
#   'https://www.federalregister.gov/documents/2020/02/24/2020-03606/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2020-02-24'],
#  ['1205-0456',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Reemployment Services and Eligibility Assessment (RESEA) Program',
#   '2019-18630',
#   'https://www.federalregister.gov/documents/2019/08/29/2019-18630/agency-information-collection-activities-submission-for-omb-review-comment-request-reemployment',
#   '2019-08-29'],
#  ['1220-0050',
#   'Information Collection Activities; Comment Request',
#   '2020-12629',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12629/information-collection-activities-comment-request',
#   '2020-06-11'],
#  ['1218-0202',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Hazardous Waste Operations and Emergency Response (HAZWOPER) Standard',
#   '2020-01395',
#   'https://www.federalregister.gov/documents/2020/01/28/2020-01395/agency-information-collection-activities-submission-for-omb-review-comment-request-hazardous-waste',
#   '2020-01-28'],
#  ['1205-0457',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Foreign Labor Certification Quarterly Activity Report',
#   '2018-23866',
#   'https://www.federalregister.gov/documents/2018/11/01/2018-23866/agency-information-collection-activities-submission-for-omb-review-comment-request-foreign-labor',
#   '2018-11-01'],
#  ['1210-0034',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1220-0157',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; National Longitudinal Survey of Youth 1997',
#   '2019-12977',
#   'https://www.federalregister.gov/documents/2019/06/19/2019-12977/agency-information-collection-activities-submission-for-omb-review-comment-request-national',
#   '2019-06-19'],
#  ['1220-0134',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Multiple Worksite Report and the Report of Federal Employment and Wages',
#   '2019-16944',
#   'https://www.federalregister.gov/documents/2019/08/08/2019-16944/agency-information-collection-activities-submission-for-omb-review-comment-request-multiple-worksite',
#   '2019-08-08'],
#  ['1218-0010',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23295',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23295/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1290-0020',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; America's Promise Evaluation",
#   '2020-11459',
#   'https://www.federalregister.gov/documents/2020/05/28/2020-11459/agency-information-collection-activities-submission-for-omb-review-comment-request-americas-promise',
#   '2020-05-28'],
#  ['1210-0101',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Notice of Special Enrollment Rights Under Group Health Plans',
#   '2019-13802',
#   'https://www.federalregister.gov/documents/2019/06/28/2019-13802/agency-information-collection-activities-submission-for-omb-review-comment-request-notice-of-special',
#   '2019-06-28'],
#  ['1205-0137',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Occupational Code Assignment',
#   '2019-18174',
#   'https://www.federalregister.gov/documents/2019/08/23/2019-18174/agency-information-collection-activities-submission-for-omb-review-comment-request-occupational-code',
#   '2019-08-23'],
#  ['1219-0065',
#   'Proposed Extension of Information Collection; Petitions for Modification of Mandatory Safety Standards',
#   '2019-03089',
#   'https://www.federalregister.gov/documents/2019/02/22/2019-03089/proposed-extension-of-information-collection-petitions-for-modification-of-mandatory-safety',
#   '2019-02-22'],
#  ['1218-0198',
#   "Logging Operations Standard; Extension of the Office of Management and Budget's (OMB) Approval of the Information Collection (Paperwork) Requirements",
#   '2020-08771',
#   'https://www.federalregister.gov/documents/2020/04/24/2020-08771/logging-operations-standard-extension-of-the-office-of-management-and-budgets-omb-approval-of-the',
#   '2020-04-24'],
#  ['1218-0183',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23295',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23295/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1218-0274',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2020-12631',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12631/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2020-06-11'],
#  ['1205-0484',
#   'Agency Information Collection Activities; Comment Request; Guam Military Base Realignment Contractor Recruitment Standards',
#   '2017-21395',
#   'https://www.federalregister.gov/documents/2017/10/05/2017-21395/agency-information-collection-activities-comment-request-guam-military-base-realignment-contractor',
#   '2017-10-05'],
#  ['1210-0134',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1218-0231',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1218-0103',
#   "Ionizing Radiation Standard; Extension of the Office of Management and Budget's (OMB) Approval of Information Collection (Paperwork) Requirements",
#   '2020-13965',
#   'https://www.federalregister.gov/documents/2020/06/29/2020-13965/ionizing-radiation-standard-extension-of-the-office-of-management-and-budgets-omb-approval-of',
#   '2020-06-29'],
#  ['1219-0020',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Operations Mining Under a Body of Water',
#   '2019-23299',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23299/agency-information-collection-activities-submission-for-omb-review-comment-request-operations-mining',
#   '2019-10-25'],
#  ['1218-0121',
#   "Standard on Powered Platforms for Building Maintenance; Extension of the Office of Management and Budget's (OMB) Approval of Information Collection (Paperwork) Requirements",
#   '2020-13176',
#   'https://www.federalregister.gov/documents/2020/06/18/2020-13176/standard-on-powered-platforms-for-building-maintenance-extension-of-the-office-of-management-and',
#   '2020-06-18'],
#  ['1240-0009',
#   'Agency Information Collection Activities; Comment Request; Notice of Recurrence (CA-2a)',
#   '2020-12771',
#   'https://www.federalregister.gov/documents/2020/06/12/2020-12771/agency-information-collection-activities-comment-request-notice-of-recurrence-ca-2a',
#   '2020-06-12'],
#  ['1205-0531',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Form ETA-9142-B-CAA-2, Attestation for Employers Seeking To Employ H-2B Nonimmigrant Workers Under Section 205 of Division M of the Consolidated Appropriations Act, 2018 Public Law 115-141',
#   '2018-26078',
#   'https://www.federalregister.gov/documents/2018/11/30/2018-26078/agency-information-collection-activities-submission-for-omb-review-comment-request-form',
#   '2018-11-30'],
#  ['1240-0008',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Rehabilitation Action Report',
#   '2017-28333',
#   'https://www.federalregister.gov/documents/2018/01/03/2017-28333/agency-information-collection-activities-submission-for-omb-review-comment-request-rehabilitation',
#   '2018-01-03'],
#  ['1218-0203',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1240-0032',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Request for State or Federal Workers' Compensation Information",
#   '2020-03767',
#   'https://www.federalregister.gov/documents/2020/02/26/2020-03767/agency-information-collection-activities-submission-for-omb-review-comment-request-request-for-state',
#   '2020-02-26'],
#  ['1220-0163',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Consumer Price Index Housing Survey',
#   '2019-03617',
#   'https://www.federalregister.gov/documents/2019/03/01/2019-03617/agency-information-collection-activities-submission-for-omb-review-comment-request-consumer-price',
#   '2019-03-01'],
#  ['1205-0001',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Work Application/Job Order Recordkeeping',
#   '2019-20391',
#   'https://www.federalregister.gov/documents/2019/09/20/2019-20391/agency-information-collection-activities-submission-for-omb-review-comment-request-work',
#   '2019-09-20'],
#  ['1240-0053',
# ...
#  ['1210-0128',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Plan Asset Transactions Determined by Independent Qualified Professional Asset Managers Under Prohibited Transaction Exemption 1984-14',
#   '2019-28049',
#   'https://www.federalregister.gov/documents/2019/12/30/2019-28049/agency-information-collection-activities-submission-for-omb-review-comment-request-plan-asset',
#   '2019-12-30'],
#  ['1218-0137',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1210-0090',
#   'Proposed Extension of Information Collection Requests for Public Comment',
#   '2018-23079',
#   'https://www.federalregister.gov/documents/2018/10/23/2018-23079/proposed-extension-of-information-collection-requests-for-public-comment',
#   '2018-10-23'],
#  ['1240-0042',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Notice of Controversion of Right to Compensation',
#   '2018-11931',
#   'https://www.federalregister.gov/documents/2018/06/04/2018-11931/agency-information-collection-activities-submission-for-omb-review-comment-request-notice-of',
#   '2018-06-04'],
#  ['1205-0010',
#   'Agency Information Collection Activities; Comment Request; Claims and Payment Activities Report',
#   '2018-15268',
#   'https://www.federalregister.gov/documents/2018/07/18/2018-15268/agency-information-collection-activities-comment-request-claims-and-payment-activities-report',
#   '2018-07-18'],
#  ['1219-0116',
#   'Proposed Extension of Information Collection; Examinations and Testing of Electrical Equipment, Including Examination, Testing, and Maintenance of High Voltage Longwalls',
#   '2020-15960',
#   'https://www.federalregister.gov/documents/2020/07/23/2020-15960/proposed-extension-of-information-collection-examinations-and-testing-of-electrical-equipment',
#   '2020-07-23'],
#  ['1220-0109',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; National Longitudinal Survey of Youth 1979',
#   '2020-12936',
#   'https://www.federalregister.gov/documents/2020/06/16/2020-12936/agency-information-collection-activities-submission-for-omb-review-comment-request-national',
#   '2020-06-16'],
#  ['1235-0021',
#   'Notice of Approved Agency Information Collection; Information Collection: Employment Information Form',
#   '2019-26011',
#   'https://www.federalregister.gov/documents/2019/12/02/2019-26011/notice-of-approved-agency-information-collection-information-collection-employment-information-form',
#   '2019-12-02'],
#  ['1235-0018',
#   'Notice of Approved Agency Information Collection; Information Collection: Records to be Kept by Employers-Fair Labor Standards Act',
#   '2019-26010',
#   'https://www.federalregister.gov/documents/2019/12/02/2019-26010/notice-of-approved-agency-information-collection-information-collection-records-to-be-kept-by',
#   '2019-12-02'],
#  ['1240-0017',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Death Gratuity',
#   '2020-07610',
#   'https://www.federalregister.gov/documents/2020/04/10/2020-07610/agency-information-collection-activities-submission-for-omb-review-comment-request-death-gratuity',
#   '2020-04-10'],
#  ['1218-0143',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Presence Sensing Device Initiation (PSDI) Standard',
#   '2020-13173',
#   'https://www.federalregister.gov/documents/2020/06/18/2020-13173/agency-information-collection-activities-submission-for-omb-review-comment-request-presence-sensing',
#   '2020-06-18'],
#  ['1218-0128',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23295',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23295/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1220-0164',
#   'Information Collection Activities; Comment Request',
#   '2020-12630',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12630/information-collection-activities-comment-request',
#   '2020-06-11'],
#  ['1210-0150',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1210-0104',
#   'Proposed Extension of Information Collection Requests for Public Comment',
#   '2018-23079',
#   'https://www.federalregister.gov/documents/2018/10/23/2018-23079/proposed-extension-of-information-collection-requests-for-public-comment',
#   '2018-10-23'],
#  ['1218-0048',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2020-12631',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12631/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2020-06-11'],
#  ['1219-0097',
#   'Proposed Extension of Information Collection; Rock Burst Control Plan, (Pertains to Underground Metal/Nonmetal Mines)',
#   '2020-10153',
#   'https://www.federalregister.gov/documents/2020/05/12/2020-10153/proposed-extension-of-information-collection-rock-burst-control-plan-pertains-to-underground',
#   '2020-05-12'],
#  ['1219-0041',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Program To Prevent Smoking in Hazardous Areas of Underground Coal Mines',
#   '2020-01121',
#   'https://www.federalregister.gov/documents/2020/01/24/2020-01121/agency-information-collection-activities-submission-for-omb-review-comment-request-program-to',
#   '2020-01-24'],
#  ['1240-0036',
#   "Agency Information Collection Activities; Comment Request; Application for Longshore and Harbor Workers' Compensation Act Pre-Hearing Statement",
#   '2020-11664',
#   'https://www.federalregister.gov/documents/2020/06/01/2020-11664/agency-information-collection-activities-comment-request-application-for-longshore-and-harbor',
#   '2020-06-01'],
#  ['1210-0121',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1218-0207',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Welding, Cutting, and Brazing Standard',
#   '2020-01506',
#   'https://www.federalregister.gov/documents/2020/01/29/2020-01506/agency-information-collection-activities-submission-for-omb-review-comment-request-welding-cutting',
#   '2020-01-29'],
#  ['1240-0014',
#   "Proposed Extension of Existing Collection; Comment Request; Administration of the Longshore and Harbor Workers' Compensation Act",
#   '2020-03910',
#   'https://www.federalregister.gov/documents/2020/02/27/2020-03910/proposed-extension-of-existing-collection-comment-request-administration-of-the-longshore-and-harbor',
#   '2020-02-27'],
#  ['1210-0146',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2019-05347',
#   'https://www.federalregister.gov/documents/2019/03/21/2019-05347/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2019-03-21'],
#  ['1205-0164',
#   'Agency Information Collection Activities; Comment Request; Experience Rating Report; Extension Without Change',
#   '2017-27758',
#   'https://www.federalregister.gov/documents/2017/12/26/2017-27758/agency-information-collection-activities-comment-request-experience-rating-report-extension-without',
#   '2017-12-26'],
#  ['1210-0064',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Class Exemption for Certain Transactions Involving Purchase of Securities Where Issuer May Use Proceeds To Reduce or Retire Indebtedness to Parties in Interest (PTE 1980-83)',
#   '2019-25254',
#   'https://www.federalregister.gov/documents/2019/11/21/2019-25254/agency-information-collection-activities-submission-for-omb-review-comment-request-class-exemption',
#   '2019-11-21'],
#  ['1205-0513',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Youthful Offender Grants Management Information System',
#   '2020-01398',
#   'https://www.federalregister.gov/documents/2020/01/28/2020-01398/agency-information-collection-activities-submission-for-omb-review-comment-request-youthful-offender',
#   '2020-01-28'],
#  ['1240-0003',
#   "Proposed Extension of Existing Collection; Comment Request; Employer's First Report of Injury or Occupational Disease (LS-202), Employer's Supplementary Report of Accident or Occupational Illness (LS-210)",
#   '2020-07358',
#   'https://www.federalregister.gov/documents/2020/04/08/2020-07358/proposed-extension-of-existing-collection-comment-request-employers-first-report-of-injury-or',
#   '2020-04-08'],
#  ['1235-0008',
#   'Agency Information Collection Activities; Announcement of OMB Approvals',
#   '2020-03606',
#   'https://www.federalregister.gov/documents/2020/02/24/2020-03606/agency-information-collection-activities-announcement-of-omb-approvals',
#   '2020-02-24'],
#  ['1219-0144',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Mine Rescue Teams; Arrangements for Emergency Medical Assistance and Transportation for Injured Persons; Agreements; Reporting Requirements; Posting Requirements',
#   '2020-03253',
#   'https://www.federalregister.gov/documents/2020/02/19/2020-03253/agency-information-collection-activities-submission-for-omb-review-comment-request-mine-rescue-teams',
#   '2020-02-19'],
#  ['1219-0007',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Mine Accident, Injury, and Illness Report and Quarterly Mine Employment and Coal Production Report',
#   '2017-21320',
#   'https://www.federalregister.gov/documents/2017/10/04/2017-21320/agency-information-collection-activities-submission-for-omb-review-comment-request-mine-accident',
#   '2017-10-04'],
#  ['1210-0124',
#   'Proposed Extension of Information Collection Requests Submitted for Public Comment',
#   '2018-07459',
#   'https://www.federalregister.gov/documents/2018/04/11/2018-07459/proposed-extension-of-information-collection-requests-submitted-for-public-comment',
#   '2018-04-11'],
#  ['1240-0023',
#   'Agency Information Collection Activities; Comment Request',
#   '2020-09968',
#   'https://www.federalregister.gov/documents/2020/05/11/2020-09968/agency-information-collection-activities-comment-request',
#   '2020-05-11'],
#  ['1205-0466',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; H-2A Temporary Agricultural Labor Certification Program',
#   '2019-11315',
#   'https://www.federalregister.gov/documents/2019/05/30/2019-11315/agency-information-collection-activities-submission-for-omb-review-comment-request-h-2a-temporary',
#   '2019-05-30'],
#  ['1205-0507',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; H-1B Technical Skills Training and Jobs and Innovation Accelerator Challenge Grants',
#   '2019-13511',
#   'https://www.federalregister.gov/documents/2019/06/26/2019-13511/agency-information-collection-activities-submission-for-omb-review-comment-request-h-1b-technical',
#   '2019-06-26'],
#  ['1219-0120',
#   'Proposed Extension of Information Collection; Occupational Noise Exposure',
#   '2018-12461',
#   'https://www.federalregister.gov/documents/2018/06/11/2018-12461/proposed-extension-of-information-collection-occupational-noise-exposure',
#   '2018-06-11'],
#  ['1218-0258',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1220-0045',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Survey of Occupational Injuries and Illnesses',
#   '2019-21611',
#   'https://www.federalregister.gov/documents/2019/10/04/2019-21611/agency-information-collection-activities-submission-for-omb-review-comment-request-survey-of',
#   '2019-10-04'],
#  ['1240-0045',
#   'Agency Information Collection Activities; Comment Request; Rehabilitation Plan and Award (OWCP-16)',
#   '2020-15833',
#   'https://www.federalregister.gov/documents/2020/07/22/2020-15833/agency-information-collection-activities-comment-request-rehabilitation-plan-and-award-owcp-16',
#   '2020-07-22'],
#  ['1218-0185',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Cadmium in General Industry Standard',
#   '2020-06902',
#   'https://www.federalregister.gov/documents/2020/04/01/2020-06902/agency-information-collection-activities-submission-for-omb-review-comment-request-cadmium-in',
#   '2020-04-01'],
#  ['1218-0265',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2019-23297',
#   'https://www.federalregister.gov/documents/2019/10/25/2019-23297/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2019-10-25'],
#  ['1240-0011',
#   "Division of Coal Mine Workers' Compensation; Proposed Extension of Existing Collection; Comment Request",
#   '2020-01376',
#   'https://www.federalregister.gov/documents/2020/01/28/2020-01376/division-of-coal-mine-workers-compensation-proposed-extension-of-existing-collection-comment-request',
#   '2020-01-28'],
#  ['1220-0196',
#   'Information Collection Activities; Comment Request',
#   '2020-12629',
#   'https://www.federalregister.gov/documents/2020/06/11/2020-12629/information-collection-activities-comment-request',
#   '2020-06-11'],
#  ['1210-0137',
#   "Agency Information Collection Activities; Submission for OMB Review; Comment Request; Model Employer Children's Health Insurance Program Notice",
#   '2019-27484',
#   'https://www.federalregister.gov/documents/2019/12/20/2019-27484/agency-information-collection-activities-submission-for-omb-review-comment-request-model-employer',
#   '2019-12-20'],
#  ['1220-0192',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Quick Survey Business Questions Test',
#   '2019-08001',
#   'https://www.federalregister.gov/documents/2019/04/22/2019-08001/agency-information-collection-activities-submission-for-omb-review-comment-request-quick-survey',
#   '2019-04-22'],
#  ['1218-0228',
#   'Agency Information Collection Activities: Announcement of the Office of Management and Budget (OMB) Control Numbers Under the Paperwork Reduction Act',
#   '2018-22917',
#   'https://www.federalregister.gov/documents/2018/10/22/2018-22917/agency-information-collection-activities-announcement-of-the-office-of-management-and-budget-omb',
#   '2018-10-22'],
#  ['1210-0040',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Employee Retirement Income Security Act Summary Annual Report Requirement',
#   '2019-08891',
#   'https://www.federalregister.gov/documents/2019/05/02/2019-08891/agency-information-collection-activities-submission-for-omb-review-comment-request-employee',
#   '2019-05-02'],
#  ['1205-0224',
#   'Agency Information Collection Activities; Submission for OMB Review; Comment Request; Equal Employment Opportunity in Apprenticeship Training',
#   '2020-01508',
#   'https://www.federalregister.gov/documents/2020/01/29/2020-01508/agency-information-collection-activities-submission-for-omb-review-comment-request-equal-employment',
#   '2020-01-29']]

# %%
notice_dataframe = pd.DataFrame(rows)

# %%
notice_dataframe.columns = ['omb_control_number','title','document_number','html_url','publication_date']

# %%
notice_dataframe
# Out:
#     omb_control_number                                              title  \
# 0            1235-0029  Agency Information Collection Activities; Subm...
# 1            1205-0132  Agency Information Collection Activities; Comm...
# 2            1218-0096  Agency Information Collection Activities: Anno...
# 3            1220-0039  Agency Information Collection Activities; Subm...
# 4            1218-0061  Agency Information Collection Activities: Anno...
# ..                 ...                                                ...
# 254          1210-0137  Agency Information Collection Activities; Subm...
# 255          1220-0192  Agency Information Collection Activities; Subm...
# 256          1218-0228  Agency Information Collection Activities: Anno...
# 257          1210-0040  Agency Information Collection Activities; Subm...
# 258          1205-0224  Agency Information Collection Activities; Subm...
#
#     document_number                                           html_url  \
# 0        2019-27332  https://www.federalregister.gov/documents/2019...
# 1        2020-09061  https://www.federalregister.gov/documents/2020...
# 2        2019-23297  https://www.federalregister.gov/documents/2019...
# 3        2020-15595  https://www.federalregister.gov/documents/2020...
# 4        2019-23295  https://www.federalregister.gov/documents/2019...
# ..              ...                                                ...
# 254      2019-27484  https://www.federalregister.gov/documents/2019...
# 255      2019-08001  https://www.federalregister.gov/documents/2019...
# 256      2018-22917  https://www.federalregister.gov/documents/2018...
# 257      2019-08891  https://www.federalregister.gov/documents/2019...
# 258      2020-01508  https://www.federalregister.gov/documents/2020...
#
#     publication_date
# 0         2019-12-19
# 1         2020-04-29
# 2         2019-10-25
# 3         2020-07-21
# 4         2019-10-25
# ..               ...
# 254       2019-12-20
# 255       2019-04-22
# 256       2018-10-22
# 257       2019-05-02
# 258       2020-01-29
#
# [259 rows x 5 columns]

# %% [markdown]
# finding the open loops that are new collections is its own project, going to finish finding the "open loops" for current inventory
# first
#
# these to do tasks are going to be after this project
# 9. search for all the new notices for dol going back a year
# 10. use the inventory to make sure that collections that were new and approved are all in that list of notices
# 11. use the pending to make sure the collections that are new and submitted are in that list.

# %%
inventory_df['expiration_date'] = pd.to_datetime(inventory_df['expiration_date'])

# %%
 inventory_df[(inventory_df['expiration_date'] < '2021-07-27') ]['omb_control_number'].to_list()
# Out:
# ['1220-0008',
#  '1220-0011',
#  '1220-0012',
#  '1220-0032',
#  '1220-0039',
#  '1220-0044',
#  '1220-0079',
#  '1220-0100',
#  '1220-0104',
#  '1220-0109',
#  '1220-0141',
#  '1220-0149',
#  '1220-0164',
#  '1220-0168',
#  '1220-0186',
#  '1220-0192',
#  '1220-0194',
#  '1220-0195',
#  '1220-0196',
#  '1220-0197',
#  '1225-0013',
#  '1225-0059',
#  '1225-0077',
#  '1225-0087',
#  '1225-0088',
#  '3046-0046',
#  '1205-0015',
#  '1205-0051',
#  '1205-0132',
#  '1205-0187',
#  '1205-0268',
#  '1205-0448',
#  '1205-0451',
#  '1205-0526',
#  '1205-0528',
#  '1205-0530',
#  '1205-0531',
#  '1219-0003',
#  '1219-0007',
#  '1219-0009',
#  '1219-0015',
#  '1219-0024',
#  '1219-0034',
#  '1219-0042',
#  '1219-0046',
#  '1219-0048',
#  '1219-0049',
#  '1219-0078',
#  '1219-0089',
#  '1219-0097',
#  '1219-0116',
#  '1219-0124',
#  '1219-0127',
#  '1219-0133',
#  '1219-0138',
#  '1219-0142',
#  '1219-0143',
#  '1219-0148',
#  '1219-0152',
#  '1218-0003',
#  '1218-0011',
#  '1218-0064',
#  '1218-0065',
#  '1218-0067',
#  '1218-0072',
#  '1218-0075',
#  '1218-0095',
#  '1218-0100',
#  '1218-0103',
#  '1218-0108',
#  '1218-0121',
#  '1218-0137',
#  '1218-0143',
#  '1218-0145',
#  '1218-0150',
#  '1218-0185',
#  '1218-0197',
#  '1218-0198',
#  '1218-0202',
#  '1218-0205',
#  '1218-0206',
#  '1218-0208',
#  '1218-0216',
#  '1218-0218',
#  '1218-0221',
#  '1218-0224',
#  '1218-0226',
#  '1218-0228',
#  '1218-0229',
#  '1218-0231',
#  '1218-0233',
#  '1218-0236',
#  '1218-0238',
#  '1218-0239',
#  '1218-0241',
#  '1218-0242',
#  '1218-0248',
#  '1218-0253',
#  '1218-0255',
#  '1218-0261',
#  '1218-0262',
#  '1218-0269',
#  '1250-0001',
#  '1240-0003',
#  '1240-0007',
#  '1240-0008',
#  '1240-0009',
#  '1240-0011',
#  '1240-0014',
#  '1240-0015',
#  '1240-0016',
#  '1240-0020',
#  '1240-0021',
#  '1240-0022',
#  '1240-0023',
#  '1240-0024',
#  '1240-0026',
#  '1240-0027',
#  '1240-0028',
#  '1240-0029',
#  '1240-0033',
#  '1240-0035',
#  '1240-0036',
#  '1240-0037',
#  '1240-0039',
#  '1240-0040',
#  '1240-0044',
#  '1240-0045',
#  '1240-0046',
#  '1293-0005',
#  '1293-0015',
#  '1290-0002',
#  '1290-0014',
#  '1290-0015',
#  '1290-0022',
#  '1235-0002',
#  '1235-0005',
#  '1235-0006',
#  '1235-0008',
#  '1235-0013',
#  '1235-0015',
#  '1235-0016',
#  '1235-0031',
#  '1235-0032',
#  '1210-0034',
#  '1210-0048',
#  '1210-0060',
#  '1210-0061',
#  '1210-0089',
#  '1210-0098',
#  '1210-0111',
#  '1210-0112',
#  '1210-0121',
#  '1210-0132',
#  '1210-0134',
#  '1210-0146']

# %%
expire_in_next_year_df = inventory_df[(inventory_df['expiration_date'] < '2021-07-27') ]

# %%
notice_dataframe['publication_date'] = pd.to_datetime(notice_dataframe['publication_date'])

# %%
expire_in_next_year_not_in_pending_df = expire_in_next_year_df[~expire_in_next_year_df.omb_control_number.isin(pending_omb_cntrl_number_list)]

# %% [markdown]
# not sure where to put the cut off, but im going to start with a year out, for all the omb_control_numbers that havent had a notice pu
# published in the last year.

# %%
published_in_the_last_year_df = notice_dataframe[(notice_dataframe['publication_date'] > '2019-07-27')]

# %%
published_in_the_last_year_list = published_in_the_last_year_df.omb_control_number.to_list()

# %%
expire_in_next_year_no_recent_notice=expire_in_next_year_not_in_pending_df[~expire_in_next_year_not_in_pending_df.omb_control_number.isin(published_in_the_last_year_list)]

# %%
expire_in_next_year_no_recent_notice.sort_values('expiration_date').head(30)
# Out:
#     omb_control_number icr_reference_number  \
# 288          1218-0261      201702-1218-003
# 28           1220-0186      201812-1220-002
# 41           3046-0046    201705-1225-015CF
# 389          1235-0002      201701-1235-002
# 392          1235-0006      201701-1235-001
# 50           1205-0015      201710-1205-006
# 153          1219-0034      201612-1219-001
# 267          1218-0226      201704-1218-002
# 289          1218-0262      201707-1218-005
# 255          1218-0208      201707-1218-001
# 403          1235-0031      202003-1235-002
# 31           1220-0194      202004-1220-008
# 40           1225-0088      201701-1225-001
# 160          1219-0049      201706-1219-004
# 202          1218-0064      201707-1218-003
# 204          1218-0067      201708-1218-002
# 158          1219-0046      201705-1219-003
# 32           1220-0195      202005-1220-001
# 215          1218-0100      201708-1218-003
# 259          1218-0218      201707-1218-002
# 265          1218-0224      201706-1218-006
# 36           1225-0059      201601-1225-004
# 208          1218-0075      201710-1218-004
# 408          1210-0048      201707-1210-002
# 414          1210-0061      201706-1210-003
# 435          1210-0111      201707-1210-001
# 182          1219-0133      201706-1219-001
# 465          1210-0146      201708-1210-002
# 370          1290-0014      201706-1290-001
# 34           1220-0197      202006-1220-005
#
#                                                  Title AgencyCode  \
# 288  Cranes and Derricks in Construction Standard  ...       1218
# 28     Current Population Survey Disability Supplement       1220
# 41                  Applicant Background Questionnaire       1225
# 389  Disclosures to Workers Under the Migrant and S...       1235
# 392  Housing Occupancy Certificate—Migrant and Seas...       1235
# 50      Application for Alien Employment Certification       1205
# 153  Records of Tests and Examinations of Mine Pers...       1219
# 267              Manlifts Standard (29 CFR 1910.68(e))       1218
# 289  Requirements for the Occupational Safety and H...       1218
# 255  Anhydrous Ammonia Storage and Handling Standar...       1218
# 403  Paid Leave Under the Families First Coronaviru...       1235
# 31   Addition of Questions to the Current Populatio...       1220
# 40   Department of Labor Generic Clearance for the ...       1225
# 160                  Hoist Operators' Physical Fitness       1219
# 202         Notice of Alleged Safety or Health Hazards       1218
# 204  Underground Construction Standard (29 CFR 1926...       1218
# 158                       Escape and Evacuation Plans        1219
# 32   National Compensation Survey related to sick l...       1220
# 215  Occupational Safety and Health Administration ...       1218
# 259  Hydrostatic Testing Provision of the Standard ...       1218
# 265  Overhead and Gantry Cranes Standard (29 CFR 19...       1218
# 36   Department of Labor Generic Solution for Outre...       1225
# 208           Fire Brigades Standard (29 CFR 1910.156)       1218
# 408  Suspension of Pension Benefits Pursuant to Reg...       1210
# 414  Employee Retirement Income Security Act Prohib...       1210
# 435  Prohibited Transaction Class Exemption 1998-54...       1210
# 182  Hazard Communication in Mining Standard (30 CF...       1219
# 465  Request for Assistance from the Department of ...       1210
# 370  Evaluation of Strategies Used in the TechHire ...       1290
# 34   United States Business Response Survey and JOL...       1220
#
#                                            ICRTypeCode     expiration_date  \
# 288  Extension without change of a currently approv... 2020-07-31 04:00:00
# 28   Reinstatement without change of a previously a... 2020-07-31 04:00:00
# 41                                 RCF Recertification 2020-07-31 04:00:00
# 389  Extension without change of a currently approv... 2020-08-31 04:00:00
# 392  Extension without change of a currently approv... 2020-08-31 04:00:00
# 50   No material or nonsubstantive change to a curr... 2020-08-31 04:00:00
# 153  Extension without change of a currently approv... 2020-09-30 04:00:00
# 267  Extension without change of a currently approv... 2020-10-31 04:00:00
# 289        Revision of a currently approved collection 2020-10-31 04:00:00
# 255  Extension without change of a currently approv... 2020-10-31 04:00:00
# 403  New collection (Request for a new OMB Control ... 2020-10-31 04:00:00
# 31   New collection (Request for a new OMB Control ... 2020-10-31 04:00:00
# 40   Extension without change of a currently approv... 2020-10-31 04:00:00
# 160  Extension without change of a currently approv... 2020-11-30 05:00:00
# 202  Extension without change of a currently approv... 2020-11-30 05:00:00
# 204  Extension without change of a currently approv... 2020-11-30 05:00:00
# 158  Extension without change of a currently approv... 2020-11-30 05:00:00
# 32   New collection (Request for a new OMB Control ... 2020-11-30 05:00:00
# 215  Extension without change of a currently approv... 2020-11-30 05:00:00
# 259  Extension without change of a currently approv... 2020-11-30 05:00:00
# 265  Extension without change of a currently approv... 2020-11-30 05:00:00
# 36         Revision of a currently approved collection 2020-11-30 05:00:00
# 208  Extension without change of a currently approv... 2020-12-31 05:00:00
# 408  Extension without change of a currently approv... 2020-12-31 05:00:00
# 414  Extension without change of a currently approv... 2020-12-31 05:00:00
# 435  Extension without change of a currently approv... 2020-12-31 05:00:00
# 182  Extension without change of a currently approv... 2021-01-31 05:00:00
# 465  Extension without change of a currently approv... 2021-01-31 05:00:00
# 370  New collection (Request for a new OMB Control ... 2021-01-31 05:00:00
# 34   New collection (Request for a new OMB Control ... 2021-01-31 05:00:00
#
#     ICR_status                 file_date
# 288     Active  2020-07-27_inventory.xml
# 28      Active  2020-07-27_inventory.xml
# 41        None  2020-07-27_inventory.xml
# 389     Active  2020-07-27_inventory.xml
# 392     Active  2020-07-27_inventory.xml
# 50      Active  2020-07-27_inventory.xml
# 153     Active  2020-07-27_inventory.xml
# 267     Active  2020-07-27_inventory.xml
# 289     Active  2020-07-27_inventory.xml
# 255     Active  2020-07-27_inventory.xml
# 403     Active  2020-07-27_inventory.xml
# 31      Active  2020-07-27_inventory.xml
# 40      Active  2020-07-27_inventory.xml
# 160     Active  2020-07-27_inventory.xml
# 202     Active  2020-07-27_inventory.xml
# 204     Active  2020-07-27_inventory.xml
# 158     Active  2020-07-27_inventory.xml
# 32      Active  2020-07-27_inventory.xml
# 215     Active  2020-07-27_inventory.xml
# 259     Active  2020-07-27_inventory.xml
# 265     Active  2020-07-27_inventory.xml
# 36      Active  2020-07-27_inventory.xml
# 208     Active  2020-07-27_inventory.xml
# 408     Active  2020-07-27_inventory.xml
# 414     Active  2020-07-27_inventory.xml
# 435     Active  2020-07-27_inventory.xml
# 182     Active  2020-07-27_inventory.xml
# 465     Active  2020-07-27_inventory.xml
# 370     Active  2020-07-27_inventory.xml
# 34      Active  2020-07-27_inventory.xml

# %%
expire_in_next_year_no_recent_notice.count()
# Out:
# omb_control_number      86
# icr_reference_number    86
# Title                   86
# AgencyCode              86
# ICRTypeCode             86
# expiration_date         86
# ICR_status              86
# file_date               86
# dtype: int64

# %%
expire_in_next_year_no_recent_notice['expire_month'] = expire_in_next_year_no_recent_notice['expiration_date'].dt.strftime('%Y-%m')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
expire_in_next_year_no_recent_notice.groupby('expire_month')['expire_month'].count()
# Out:
# expire_month
# 2020-07     3
# 2020-08     3
# 2020-09     1
# 2020-10     6
# 2020-11     9
# 2020-12     4
# 2021-01    13
# 2021-02    17
# 2021-03     4
# 2021-04    12
# 2021-05     7
# 2021-06     7
# Name: expire_month, dtype: int64

# %%
expire_in_next_year_not_in_pending_df['expire_month'] = expire_in_next_year_not_in_pending_df['expiration_date'].dt.strftime('%Y-%m')


expire_in_next_year_not_in_pending_df.groupby('expire_month')['expire_month'].count()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# expire_month
# 2020-07     3
# 2020-08     9
# 2020-09     6
# 2020-10    15
# 2020-11    14
# 2020-12     9
# 2021-01    14
# 2021-02    18
# 2021-03     4
# 2021-04    14
# 2021-05     7
# 2021-06     8
# Name: expire_month, dtype: int64

# %% [markdown]
# # Part 2
#
# from the top, we have number 11 and 12 done.
#
# 14 is going to have to be its own project.
#
# for now , the next step in this project is to create something that monitors the cycle time and lead time
#
# to do this i need to use a database
#
# so the next part will be connecting to the database and create the tables needed to monitor that information.
