# %%
import daily_ingestor

# %%
import report_builder
# Out:
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# cant save
# ...
